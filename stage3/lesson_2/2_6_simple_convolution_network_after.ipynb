# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/E資格/ステージ３')

# %% [markdown]
# # simple convolution network

# %% [markdown]
# ## image to column

# %%
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from common import optimizer
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# 画像データを２次元配列に変換
'''
input_data: 入力値
filter_h: フィルターの高さ
filter_w: フィルターの横幅
stride: ストライド
pad: パディング
'''
def im2col(input_data, filter_h, filter_w, stride=1, pad=0):
    # N: number, C: channel, H: height, W: width
    N, C, H, W = input_data.shape
    # 切り捨て除算
    out_h = (H + 2 * pad - filter_h)//stride + 1
    out_w = (W + 2 * pad - filter_w)//stride + 1

    img = np.pad(input_data, [(0,0), (0,0), (pad, pad), (pad, pad)], 'constant')
    col = np.zeros((N, C, filter_h, filter_w, out_h, out_w))

    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            col[:, :, y, x, :, :] = img[:, :, y:y_max:stride, x:x_max:stride]

    col = col.transpose(0, 4, 5, 1, 2, 3) # (N, C, filter_h, filter_w, out_h, out_w) -> (N, filter_w, out_h, out_w, C, filter_h)    
    
    col = col.reshape(N * out_h * out_w, -1)
    return col

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] im2colの処理を確認しよう
# ・関数内でtransposeの処理をしている行をコメントアウトして下のコードを実行してみよう<br>
# ・input_dataの各次元のサイズやフィルターサイズ・ストライド・パディングを変えてみよう
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# im2colの処理確認
input_data = np.random.rand(2, 1, 4, 4)*100//1 # number, channel, height, widthを表す
print('========== input_data ===========\n', input_data)
print('==============================')
filter_h = 3
filter_w = 3
stride = 1
pad = 0
col = im2col(input_data, filter_h=filter_h, filter_w=filter_w, stride=stride, pad=pad)
print('============= col ==============\n', col)
print('==============================')
# Out:
# ========== input_data ===========
#  [[[[ 9. 91.  8. 13.]
#    [38. 21. 64. 44.]
#    [85. 70. 75. 54.]
#    [11. 71. 33. 59.]]]
#
#
#  [[[28. 71. 83. 72.]
#    [ 3. 15.  1.  4.]
#    [ 6. 24. 56. 58.]
#    [94. 28. 48. 30.]]]]
# ==============================
# ============= col ==============
#  [[ 9. 91.  8. 38. 21. 64. 85. 70. 75.]
#  [91.  8. 13. 21. 64. 44. 70. 75. 54.]
#  [38. 21. 64. 85. 70. 75. 11. 71. 33.]
#  [21. 64. 44. 70. 75. 54. 71. 33. 59.]
#  [28. 71. 83.  3. 15.  1.  6. 24. 56.]
#  [71. 83. 72. 15.  1.  4. 24. 56. 58.]
#  [ 3. 15.  1.  6. 24. 56. 94. 28. 48.]
#  [15.  1.  4. 24. 56. 58. 28. 48. 30.]]
# ==============================

# %% [markdown]
# ## column to image

# %%
# ２次元配列を画像データに変換
def col2im(col, input_shape, filter_h, filter_w, stride=1, pad=0):
    # N: number, C: channel, H: height, W: width
    N, C, H, W = input_shape
    # 切り捨て除算    
    out_h = (H + 2 * pad - filter_h)//stride + 1
    out_w = (W + 2 * pad - filter_w)//stride + 1
    col = col.reshape(N, out_h, out_w, C, filter_h, filter_w).transpose(0, 3, 4, 5, 1, 2) # (N, filter_h, filter_w, out_h, out_w, C)

    img = np.zeros((N, C, H + 2 * pad + stride - 1, W + 2 * pad + stride - 1))
    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            img[:, :, y:y_max:stride, x:x_max:stride] += col[:, :, y, x, :, :]

    return img[:, :, pad:H + pad, pad:W + pad]

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] col2imの処理を確認しよう
# ・im2colの確認で出力したcolをimageに変換して確認しよう
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# ここにcol2imでの処理を書こう
img = col2im(col, input_shape=input_data.shape, filter_h=filter_h, filter_w=filter_w, stride=stride, pad=pad)
print(img)
# Out:
# [[[[  9. 182.  16.  13.]
#    [ 76.  84. 256.  88.]
#    [170. 280. 300. 108.]
#    [ 11. 142.  66.  59.]]]
#
#
#  [[[ 28. 142. 166.  72.]
#    [  6.  60.   4.   8.]
#    [ 12.  96. 224. 116.]
#    [ 94.  56.  96.  30.]]]]

# %% [markdown]
# ## convolution class

# %%
class Convolution:
    # W: フィルター, b: バイアス
    def __init__(self, W, b, stride=1, pad=0):
        self.W = W
        self.b = b
        self.stride = stride
        self.pad = pad
        
        # 中間データ（backward時に使用）
        self.x = None   
        self.col = None
        self.col_W = None
        
        # フィルター・バイアスパラメータの勾配
        self.dW = None
        self.db = None

    def forward(self, x):
        # FN: filter_number, C: channel, FH: filter_height, FW: filter_width
        FN, C, FH, FW = self.W.shape
        N, C, H, W = x.shape
        # 出力値のheight, width
        out_h = 1 + int((H + 2 * self.pad - FH) / self.stride)
        out_w = 1 + int((W + 2 * self.pad - FW) / self.stride)
        
        # xを行列に変換
        col = im2col(x, FH, FW, self.stride, self.pad)
        # フィルターをxに合わせた行列に変換
        col_W = self.W.reshape(FN, -1).T

        out = np.dot(col, col_W) + self.b
        # 計算のために変えた形式を戻す
        out = out.reshape(N, out_h, out_w, -1).transpose(0, 3, 1, 2)

        self.x = x
        self.col = col
        self.col_W = col_W

        return out

    def backward(self, dout):
        FN, C, FH, FW = self.W.shape
        dout = dout.transpose(0, 2, 3, 1).reshape(-1, FN)

        self.db = np.sum(dout, axis=0)
        self.dW = np.dot(self.col.T, dout)
        self.dW = self.dW.transpose(1, 0).reshape(FN, C, FH, FW)

        dcol = np.dot(dout, self.col_W.T)
        # dcolを画像データに変換
        dx = col2im(dcol, self.x.shape, FH, FW, self.stride, self.pad)

        return dx

# %% [markdown]
# ## pooling class

# %%
class Pooling:
    def __init__(self, pool_h, pool_w, stride=1, pad=0):
        self.pool_h = pool_h
        self.pool_w = pool_w
        self.stride = stride
        self.pad = pad
        
        self.x = None
        self.arg_max = None

    def forward(self, x):
        N, C, H, W = x.shape
        out_h = int(1 + (H - self.pool_h) / self.stride)
        out_w = int(1 + (W - self.pool_w) / self.stride)
        
        # xを行列に変換
        col = im2col(x, self.pool_h, self.pool_w, self.stride, self.pad)
        # プーリングのサイズに合わせてリサイズ
        col = col.reshape(-1, self.pool_h*self.pool_w)
        
        #maxプーリング
        arg_max = np.argmax(col, axis=1)
        out = np.max(col, axis=1)
        out = out.reshape(N, out_h, out_w, C).transpose(0, 3, 1, 2)

        self.x = x
        self.arg_max = arg_max

        return out

    def backward(self, dout):
        dout = dout.transpose(0, 2, 3, 1)
        
        pool_size = self.pool_h * self.pool_w
        dmax = np.zeros((dout.size, pool_size))
        dmax[np.arange(self.arg_max.size), self.arg_max.flatten()] = dout.flatten()
        dmax = dmax.reshape(dout.shape + (pool_size,)) 
        
        dcol = dmax.reshape(dmax.shape[0] * dmax.shape[1] * dmax.shape[2], -1)
        dx = col2im(dcol, self.x.shape, self.pool_h, self.pool_w, self.stride, self.pad)
        
        return dx

# %% [markdown]
# ## sinple convolution network class

# %%
class SimpleConvNet:
    # conv - relu - pool - affine - relu - affine - softmax
    def __init__(self, input_dim=(1, 28, 28), conv_param={'filter_num':30, 'filter_size':5, 'pad':0, 'stride':1},
                 hidden_size=100, output_size=10, weight_init_std=0.01):
        filter_num = conv_param['filter_num']        
        filter_size = conv_param['filter_size']
        filter_pad = conv_param['pad']
        filter_stride = conv_param['stride']
        input_size = input_dim[1]
        conv_output_size = (input_size - filter_size + 2 * filter_pad) / filter_stride + 1
        pool_output_size = int(filter_num * (conv_output_size / 2) * (conv_output_size / 2))

        # 重みの初期化
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(filter_num, input_dim[0], filter_size, filter_size)
        self.params['b1'] = np.zeros(filter_num)
        self.params['W2'] = weight_init_std * np.random.randn(pool_output_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size)

        # レイヤの生成
        self.layers = OrderedDict()
        self.layers['Conv1'] = layers.Convolution(self.params['W1'], self.params['b1'], conv_param['stride'], conv_param['pad'])
        self.layers['Relu1'] = layers.Relu()
        self.layers['Pool1'] = layers.Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Affine1'] = layers.Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = layers.Relu()
        self.layers['Affine2'] = layers.Affine(self.params['W3'], self.params['b3'])

        self.last_layer = layers.SoftmaxWithLoss()

    def predict(self, x):
        for key in self.layers.keys():
            x = self.layers[key].forward(x)
        return x
        
    def loss(self, x, d):
        y = self.predict(x)
        return self.last_layer.forward(y, d)

    def accuracy(self, x, d, batch_size=100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)
        
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td) 
        
        return acc / x.shape[0]

    def gradient(self, x, d):
        # forward
        self.loss(x, d)
        
        # backward
        dout = 1
        dout = self.last_layer.backward(dout)
        layers = list(self.layers.values())
        
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        grad['W1'], grad['b1'] = self.layers['Conv1'].dW, self.layers['Conv1'].db
        grad['W2'], grad['b2'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
        grad['W3'], grad['b3'] = self.layers['Affine2'].dW, self.layers['Affine2'].db

        return grad

# %%
from common import optimizer

# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

print("データ読み込み完了")

# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]


network = SimpleConvNet(input_dim=(1,28,28), conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
                        hidden_size=100, output_size=10, weight_init_std=0.01)

optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10



for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)

    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.3916
#                 : 10. 正答率(テスト) = 0.317
# Generation: 20. 正答率(トレーニング) = 0.668
#                 : 20. 正答率(テスト) = 0.628
# Generation: 30. 正答率(トレーニング) = 0.737
#                 : 30. 正答率(テスト) = 0.692
# Generation: 40. 正答率(トレーニング) = 0.803
#                 : 40. 正答率(テスト) = 0.774
# Generation: 50. 正答率(トレーニング) = 0.843
#                 : 50. 正答率(テスト) = 0.826
# Generation: 60. 正答率(トレーニング) = 0.8674
#                 : 60. 正答率(テスト) = 0.847
# Generation: 70. 正答率(トレーニング) = 0.877
#                 : 70. 正答率(テスト) = 0.842
# Generation: 80. 正答率(トレーニング) = 0.8842
#                 : 80. 正答率(テスト) = 0.855
# Generation: 90. 正答率(トレーニング) = 0.8854
#                 : 90. 正答率(テスト) = 0.86
# Generation: 100. 正答率(トレーニング) = 0.8916
#                 : 100. 正答率(テスト) = 0.861
# Generation: 110. 正答率(トレーニング) = 0.8926
#                 : 110. 正答率(テスト) = 0.856
# Generation: 120. 正答率(トレーニング) = 0.905
#                 : 120. 正答率(テスト) = 0.868
# Generation: 130. 正答率(トレーニング) = 0.9056
#                 : 130. 正答率(テスト) = 0.861
# Generation: 140. 正答率(トレーニング) = 0.9026
#                 : 140. 正答率(テスト) = 0.87
# Generation: 150. 正答率(トレーニング) = 0.9204
#                 : 150. 正答率(テスト) = 0.879
# Generation: 160. 正答率(トレーニング) = 0.9214
#                 : 160. 正答率(テスト) = 0.889
# Generation: 170. 正答率(トレーニング) = 0.9096
#                 : 170. 正答率(テスト) = 0.885
# Generation: 180. 正答率(トレーニング) = 0.928
#                 : 180. 正答率(テスト) = 0.897
# Generation: 190. 正答率(トレーニング) = 0.9294
#                 : 190. 正答率(テスト) = 0.902
# Generation: 200. 正答率(トレーニング) = 0.9314
#                 : 200. 正答率(テスト) = 0.906
# Generation: 210. 正答率(トレーニング) = 0.9314
#                 : 210. 正答率(テスト) = 0.902
# Generation: 220. 正答率(トレーニング) = 0.926
#                 : 220. 正答率(テスト) = 0.901
# Generation: 230. 正答率(トレーニング) = 0.939
#                 : 230. 正答率(テスト) = 0.902
# Generation: 240. 正答率(トレーニング) = 0.9372
#                 : 240. 正答率(テスト) = 0.909
# Generation: 250. 正答率(トレーニング) = 0.9414
#                 : 250. 正答率(テスト) = 0.913
# Generation: 260. 正答率(トレーニング) = 0.9374
#                 : 260. 正答率(テスト) = 0.918
# Generation: 270. 正答率(トレーニング) = 0.938
#                 : 270. 正答率(テスト) = 0.908
# Generation: 280. 正答率(トレーニング) = 0.9398
#                 : 280. 正答率(テスト) = 0.917
# Generation: 290. 正答率(トレーニング) = 0.9504
#                 : 290. 正答率(テスト) = 0.923
# Generation: 300. 正答率(トレーニング) = 0.9474
#                 : 300. 正答率(テスト) = 0.909
# Generation: 310. 正答率(トレーニング) = 0.9424
#                 : 310. 正答率(テスト) = 0.91
# Generation: 320. 正答率(トレーニング) = 0.9514
#                 : 320. 正答率(テスト) = 0.912
# Generation: 330. 正答率(トレーニング) = 0.9536
#                 : 330. 正答率(テスト) = 0.926
# Generation: 340. 正答率(トレーニング) = 0.9554
#                 : 340. 正答率(テスト) = 0.92
# Generation: 350. 正答率(トレーニング) = 0.9514
#                 : 350. 正答率(テスト) = 0.917
# Generation: 360. 正答率(トレーニング) = 0.9566
#                 : 360. 正答率(テスト) = 0.923
# Generation: 370. 正答率(トレーニング) = 0.953
#                 : 370. 正答率(テスト) = 0.919
# Generation: 380. 正答率(トレーニング) = 0.9614
#                 : 380. 正答率(テスト) = 0.929
# Generation: 390. 正答率(トレーニング) = 0.9584
#                 : 390. 正答率(テスト) = 0.925
# Generation: 400. 正答率(トレーニング) = 0.963
#                 : 400. 正答率(テスト) = 0.931
# Generation: 410. 正答率(トレーニング) = 0.9604
#                 : 410. 正答率(テスト) = 0.928
# Generation: 420. 正答率(トレーニング) = 0.962
#                 : 420. 正答率(テスト) = 0.921
# Generation: 430. 正答率(トレーニング) = 0.9614
#                 : 430. 正答率(テスト) = 0.924
# Generation: 440. 正答率(トレーニング) = 0.9658
#                 : 440. 正答率(テスト) = 0.926
# Generation: 450. 正答率(トレーニング) = 0.9602
#                 : 450. 正答率(テスト) = 0.922
# Generation: 460. 正答率(トレーニング) = 0.9656
#                 : 460. 正答率(テスト) = 0.928
# Generation: 470. 正答率(トレーニング) = 0.9652
#                 : 470. 正答率(テスト) = 0.933
# Generation: 480. 正答率(トレーニング) = 0.9698
#                 : 480. 正答率(テスト) = 0.927
# Generation: 490. 正答率(トレーニング) = 0.9712
#                 : 490. 正答率(テスト) = 0.933
# Generation: 500. 正答率(トレーニング) = 0.9732
#                 : 500. 正答率(テスト) = 0.934
# Generation: 510. 正答率(トレーニング) = 0.9714
#                 : 510. 正答率(テスト) = 0.93
# Generation: 520. 正答率(トレーニング) = 0.9708
#                 : 520. 正答率(テスト) = 0.932
# Generation: 530. 正答率(トレーニング) = 0.977
#                 : 530. 正答率(テスト) = 0.934
# Generation: 540. 正答率(トレーニング) = 0.9766
#                 : 540. 正答率(テスト) = 0.937
# Generation: 550. 正答率(トレーニング) = 0.9794
#                 : 550. 正答率(テスト) = 0.947
# Generation: 560. 正答率(トレーニング) = 0.9756
#                 : 560. 正答率(テスト) = 0.935
# Generation: 570. 正答率(トレーニング) = 0.9744
#                 : 570. 正答率(テスト) = 0.935
# Generation: 580. 正答率(トレーニング) = 0.969
#                 : 580. 正答率(テスト) = 0.935
# Generation: 590. 正答率(トレーニング) = 0.972
#                 : 590. 正答率(テスト) = 0.93
# Generation: 600. 正答率(トレーニング) = 0.9746
#                 : 600. 正答率(テスト) = 0.936
# Generation: 610. 正答率(トレーニング) = 0.9738
#                 : 610. 正答率(テスト) = 0.934
# Generation: 620. 正答率(トレーニング) = 0.9772
#                 : 620. 正答率(テスト) = 0.942
# Generation: 630. 正答率(トレーニング) = 0.9832
#                 : 630. 正答率(テスト) = 0.952
# Generation: 640. 正答率(トレーニング) = 0.979
#                 : 640. 正答率(テスト) = 0.948
# Generation: 650. 正答率(トレーニング) = 0.9752
#                 : 650. 正答率(テスト) = 0.943
# Generation: 660. 正答率(トレーニング) = 0.9792
#                 : 660. 正答率(テスト) = 0.946
# Generation: 670. 正答率(トレーニング) = 0.9832
#                 : 670. 正答率(テスト) = 0.948
# Generation: 680. 正答率(トレーニング) = 0.985
#                 : 680. 正答率(テスト) = 0.946
# Generation: 690. 正答率(トレーニング) = 0.9828
#                 : 690. 正答率(テスト) = 0.944
# Generation: 700. 正答率(トレーニング) = 0.9852
#                 : 700. 正答率(テスト) = 0.952
# Generation: 710. 正答率(トレーニング) = 0.9876
#                 : 710. 正答率(テスト) = 0.943
# Generation: 720. 正答率(トレーニング) = 0.9884
#                 : 720. 正答率(テスト) = 0.952
# Generation: 730. 正答率(トレーニング) = 0.9886
#                 : 730. 正答率(テスト) = 0.955
# Generation: 740. 正答率(トレーニング) = 0.9836
#                 : 740. 正答率(テスト) = 0.952
# Generation: 750. 正答率(トレーニング) = 0.9852
#                 : 750. 正答率(テスト) = 0.945
# Generation: 760. 正答率(トレーニング) = 0.9872
#                 : 760. 正答率(テスト) = 0.952
# Generation: 770. 正答率(トレーニング) = 0.9884
#                 : 770. 正答率(テスト) = 0.953
# Generation: 780. 正答率(トレーニング) = 0.9886
#                 : 780. 正答率(テスト) = 0.958
# Generation: 790. 正答率(トレーニング) = 0.9902
#                 : 790. 正答率(テスト) = 0.956
# Generation: 800. 正答率(トレーニング) = 0.989
#                 : 800. 正答率(テスト) = 0.948
# Generation: 810. 正答率(トレーニング) = 0.9896
#                 : 810. 正答率(テスト) = 0.954
# Generation: 820. 正答率(トレーニング) = 0.9908
#                 : 820. 正答率(テスト) = 0.952
# Generation: 830. 正答率(トレーニング) = 0.9912
#                 : 830. 正答率(テスト) = 0.954
# Generation: 840. 正答率(トレーニング) = 0.9932
#                 : 840. 正答率(テスト) = 0.956
# Generation: 850. 正答率(トレーニング) = 0.9924
#                 : 850. 正答率(テスト) = 0.955
# Generation: 860. 正答率(トレーニング) = 0.9908
#                 : 860. 正答率(テスト) = 0.954
# Generation: 870. 正答率(トレーニング) = 0.9924
#                 : 870. 正答率(テスト) = 0.96
# Generation: 880. 正答率(トレーニング) = 0.9912
#                 : 880. 正答率(テスト) = 0.954
# Generation: 890. 正答率(トレーニング) = 0.9914
#                 : 890. 正答率(テスト) = 0.959
# Generation: 900. 正答率(トレーニング) = 0.9918
#                 : 900. 正答率(テスト) = 0.959
# Generation: 910. 正答率(トレーニング) = 0.9914
#                 : 910. 正答率(テスト) = 0.954
# Generation: 920. 正答率(トレーニング) = 0.9876
#                 : 920. 正答率(テスト) = 0.941
# Generation: 930. 正答率(トレーニング) = 0.9942
#                 : 930. 正答率(テスト) = 0.954
# Generation: 940. 正答率(トレーニング) = 0.9934
#                 : 940. 正答率(テスト) = 0.955
# Generation: 950. 正答率(トレーニング) = 0.995
#                 : 950. 正答率(テスト) = 0.96
# Generation: 960. 正答率(トレーニング) = 0.9954
#                 : 960. 正答率(テスト) = 0.958
# Generation: 970. 正答率(トレーニング) = 0.9946
#                 : 970. 正答率(テスト) = 0.957
# Generation: 980. 正答率(トレーニング) = 0.9936
#                 : 980. 正答率(テスト) = 0.959
# Generation: 990. 正答率(トレーニング) = 0.9912
#                 : 990. 正答率(テスト) = 0.95
# Generation: 1000. 正答率(トレーニング) = 0.9956
#                 : 1000. 正答率(テスト) = 0.96
