# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/MyDrive/E資格/ステージ３')

# %% [markdown]
# # vanishing gradient modified

# %% [markdown]
# ## multi layer network class

# %%
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt


class MultiLayerNet:
    '''
    input_size: 入力層のノード数
    hidden_size_list: 隠れ層のノード数のリスト
    output_size: 出力層のノード数
    activation: 活性化関数
    weight_init_std: 重みの初期化方法
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation='relu', weight_init_std='relu'):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.params = {}

        # 重みの初期化
        self.__init_weight(weight_init_std)

        # レイヤの生成, sigmoidとreluのみ扱う
        activation_layer = {'sigmoid': layers.Sigmoid, 'relu': layers.Relu}
        self.layers = OrderedDict() # 追加した順番に格納
        for idx in range(1, self.hidden_layer_num+1):
            self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])
            self.layers['Activation_function' + str(idx)] = activation_layer[activation]()

        idx = self.hidden_layer_num + 1
        self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])

        self.last_layer = layers.SoftmaxWithLoss()

    def __init_weight(self, weight_init_std):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = weight_init_std
            if str(weight_init_std).lower() in ('relu', 'he'):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(weight_init_std).lower() in ('sigmoid', 'xavier'):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])

            self.params['W' + str(idx)] = scale * np.random.randn(all_size_list[idx-1], all_size_list[idx])
            self.params['b' + str(idx)] = np.zeros(all_size_list[idx])

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    def loss(self, x, d):
        y = self.predict(x)

        weight_decay = 0
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params['W' + str(idx)]

        return self.last_layer.forward(y, d) + weight_decay

    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        for idx in range(1, self.hidden_layer_num+2):
            grad['W' + str(idx)] = self.layers['Affine' + str(idx)].dW
            grad['b' + str(idx)] = self.layers['Affine' + str(idx)].db

        return grad

# %% [markdown]
# ## vanishing sample
# ## sigmoid - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.14
#                 : 10. 正答率(テスト) = 0.0892
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.12
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.12
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.1
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.12
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.15
#                 : 70. 正答率(テスト) = 0.101
# Generation: 80. 正答率(トレーニング) = 0.14
#                 : 80. 正答率(テスト) = 0.101
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.07
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.09
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.11
#                 : 120. 正答率(テスト) = 0.1028
# Generation: 130. 正答率(トレーニング) = 0.04
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.1
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.08
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.16
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.12
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.11
#                 : 190. 正答率(テスト) = 0.1028
# Generation: 200. 正答率(トレーニング) = 0.15
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1028
# Generation: 220. 正答率(トレーニング) = 0.09
#                 : 220. 正答率(テスト) = 0.1028
# Generation: 230. 正答率(トレーニング) = 0.12
#                 : 230. 正答率(テスト) = 0.1028
# Generation: 240. 正答率(トレーニング) = 0.18
#                 : 240. 正答率(テスト) = 0.1032
# Generation: 250. 正答率(トレーニング) = 0.19
#                 : 250. 正答率(テスト) = 0.1032
# Generation: 260. 正答率(トレーニング) = 0.16
#                 : 260. 正答率(テスト) = 0.1028
# Generation: 270. 正答率(トレーニング) = 0.11
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.09
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.12
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.1
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.14
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.09
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.15
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.08
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.19
#                 : 350. 正答率(テスト) = 0.1032
# Generation: 360. 正答率(トレーニング) = 0.15
#                 : 360. 正答率(テスト) = 0.1032
# Generation: 370. 正答率(トレーニング) = 0.1
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.07
#                 : 380. 正答率(テスト) = 0.101
# Generation: 390. 正答率(トレーニング) = 0.11
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.11
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.12
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.08
#                 : 420. 正答率(テスト) = 0.1028
# Generation: 430. 正答率(トレーニング) = 0.14
#                 : 430. 正答率(テスト) = 0.101
# Generation: 440. 正答率(トレーニング) = 0.06
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.12
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.12
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.101
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.09
#                 : 490. 正答率(テスト) = 0.098
# Generation: 500. 正答率(トレーニング) = 0.12
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.09
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.12
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.18
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.1
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.1
#                 : 560. 正答率(テスト) = 0.1028
# Generation: 570. 正答率(トレーニング) = 0.14
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.15
#                 : 580. 正答率(テスト) = 0.1028
# Generation: 590. 正答率(トレーニング) = 0.14
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.08
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.09
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.14
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.08
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.1
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.08
#                 : 650. 正答率(テスト) = 0.101
# Generation: 660. 正答率(トレーニング) = 0.12
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.11
#                 : 670. 正答率(テスト) = 0.101
# Generation: 680. 正答率(トレーニング) = 0.09
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.12
#                 : 690. 正答率(テスト) = 0.1028
# Generation: 700. 正答率(トレーニング) = 0.07
#                 : 700. 正答率(テスト) = 0.1028
# Generation: 710. 正答率(トレーニング) = 0.1
#                 : 710. 正答率(テスト) = 0.1028
# Generation: 720. 正答率(トレーニング) = 0.11
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1028
# Generation: 740. 正答率(トレーニング) = 0.18
#                 : 740. 正答率(テスト) = 0.1028
# Generation: 750. 正答率(トレーニング) = 0.13
#                 : 750. 正答率(テスト) = 0.101
# Generation: 760. 正答率(トレーニング) = 0.1
#                 : 760. 正答率(テスト) = 0.101
# Generation: 770. 正答率(トレーニング) = 0.12
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.14
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.1
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.11
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.08
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.1
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.11
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.11
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.11
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.14
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.14
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.17
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.09
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.16
#                 : 900. 正答率(テスト) = 0.1028
# Generation: 910. 正答率(トレーニング) = 0.08
#                 : 910. 正答率(テスト) = 0.1028
# Generation: 920. 正答率(トレーニング) = 0.12
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.1
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.14
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.1
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.13
#                 : 960. 正答率(テスト) = 0.1028
# Generation: 970. 正答率(トレーニング) = 0.13
#                 : 970. 正答率(テスト) = 0.0974
# Generation: 980. 正答率(トレーニング) = 0.14
#                 : 980. 正答率(テスト) = 0.0958
# Generation: 990. 正答率(トレーニング) = 0.12
#                 : 990. 正答率(テスト) = 0.101
# Generation: 1000. 正答率(トレーニング) = 0.16
#                 : 1000. 正答率(テスト) = 0.101
# Generation: 1010. 正答率(トレーニング) = 0.19
#                 : 1010. 正答率(テスト) = 0.1135
# Generation: 1020. 正答率(トレーニング) = 0.14
#                 : 1020. 正答率(テスト) = 0.1135
# Generation: 1030. 正答率(トレーニング) = 0.08
#                 : 1030. 正答率(テスト) = 0.1135
# Generation: 1040. 正答率(トレーニング) = 0.11
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.1
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.08
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.11
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.12
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.14
#                 : 1090. 正答率(テスト) = 0.101
# Generation: 1100. 正答率(トレーニング) = 0.11
#                 : 1100. 正答率(テスト) = 0.098
# Generation: 1110. 正答率(トレーニング) = 0.13
#                 : 1110. 正答率(テスト) = 0.1009
# Generation: 1120. 正答率(トレーニング) = 0.12
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.1
#                 : 1130. 正答率(テスト) = 0.1135
# Generation: 1140. 正答率(トレーニング) = 0.06
#                 : 1140. 正答率(テスト) = 0.1135
# Generation: 1150. 正答率(トレーニング) = 0.07
#                 : 1150. 正答率(テスト) = 0.1135
# Generation: 1160. 正答率(トレーニング) = 0.13
#                 : 1160. 正答率(テスト) = 0.1135
# Generation: 1170. 正答率(トレーニング) = 0.09
#                 : 1170. 正答率(テスト) = 0.0974
# Generation: 1180. 正答率(トレーニング) = 0.05
#                 : 1180. 正答率(テスト) = 0.0974
# Generation: 1190. 正答率(トレーニング) = 0.2
#                 : 1190. 正答率(テスト) = 0.1028
# Generation: 1200. 正答率(トレーニング) = 0.13
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.11
#                 : 1210. 正答率(テスト) = 0.1135
# Generation: 1220. 正答率(トレーニング) = 0.1
#                 : 1220. 正答率(テスト) = 0.1028
# Generation: 1230. 正答率(トレーニング) = 0.1
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.11
#                 : 1240. 正答率(テスト) = 0.1135
# Generation: 1250. 正答率(トレーニング) = 0.09
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.13
#                 : 1260. 正答率(テスト) = 0.1135
# Generation: 1270. 正答率(トレーニング) = 0.1
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.13
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.17
#                 : 1290. 正答率(テスト) = 0.1135
# Generation: 1300. 正答率(トレーニング) = 0.06
#                 : 1300. 正答率(テスト) = 0.1135
# Generation: 1310. 正答率(トレーニング) = 0.12
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.15
#                 : 1320. 正答率(テスト) = 0.1135
# Generation: 1330. 正答率(トレーニング) = 0.11
#                 : 1330. 正答率(テスト) = 0.1135
# Generation: 1340. 正答率(トレーニング) = 0.11
#                 : 1340. 正答率(テスト) = 0.101
# Generation: 1350. 正答率(トレーニング) = 0.11
#                 : 1350. 正答率(テスト) = 0.1135
# Generation: 1360. 正答率(トレーニング) = 0.06
#                 : 1360. 正答率(テスト) = 0.0958
# Generation: 1370. 正答率(トレーニング) = 0.12
#                 : 1370. 正答率(テスト) = 0.1135
# Generation: 1380. 正答率(トレーニング) = 0.12
#                 : 1380. 正答率(テスト) = 0.1028
# Generation: 1390. 正答率(トレーニング) = 0.15
#                 : 1390. 正答率(テスト) = 0.098
# Generation: 1400. 正答率(トレーニング) = 0.09
#                 : 1400. 正答率(テスト) = 0.1135
# Generation: 1410. 正答率(トレーニング) = 0.12
#                 : 1410. 正答率(テスト) = 0.1135
# Generation: 1420. 正答率(トレーニング) = 0.1
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.07
#                 : 1430. 正答率(テスト) = 0.1028
# Generation: 1440. 正答率(トレーニング) = 0.15
#                 : 1440. 正答率(テスト) = 0.1135
# Generation: 1450. 正答率(トレーニング) = 0.15
#                 : 1450. 正答率(テスト) = 0.1135
# Generation: 1460. 正答率(トレーニング) = 0.13
#                 : 1460. 正答率(テスト) = 0.1135
# Generation: 1470. 正答率(トレーニング) = 0.15
#                 : 1470. 正答率(テスト) = 0.101
# Generation: 1480. 正答率(トレーニング) = 0.09
#                 : 1480. 正答率(テスト) = 0.101
# Generation: 1490. 正答率(トレーニング) = 0.13
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.09
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.12
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.15
#                 : 1520. 正答率(テスト) = 0.1028
# Generation: 1530. 正答率(トレーニング) = 0.14
#                 : 1530. 正答率(テスト) = 0.1135
# Generation: 1540. 正答率(トレーニング) = 0.08
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.1
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.1
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.12
#                 : 1570. 正答率(テスト) = 0.1032
# Generation: 1580. 正答率(トレーニング) = 0.09
#                 : 1580. 正答率(テスト) = 0.1135
# Generation: 1590. 正答率(トレーニング) = 0.12
#                 : 1590. 正答率(テスト) = 0.1135
# Generation: 1600. 正答率(トレーニング) = 0.13
#                 : 1600. 正答率(テスト) = 0.1135
# Generation: 1610. 正答率(トレーニング) = 0.06
#                 : 1610. 正答率(テスト) = 0.1135
# Generation: 1620. 正答率(トレーニング) = 0.13
#                 : 1620. 正答率(テスト) = 0.1135
# Generation: 1630. 正答率(トレーニング) = 0.07
#                 : 1630. 正答率(テスト) = 0.1135
# Generation: 1640. 正答率(トレーニング) = 0.11
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.09
#                 : 1650. 正答率(テスト) = 0.1028
# Generation: 1660. 正答率(トレーニング) = 0.12
#                 : 1660. 正答率(テスト) = 0.1135
# Generation: 1670. 正答率(トレーニング) = 0.1
#                 : 1670. 正答率(テスト) = 0.1135
# Generation: 1680. 正答率(トレーニング) = 0.16
#                 : 1680. 正答率(テスト) = 0.1028
# Generation: 1690. 正答率(トレーニング) = 0.13
#                 : 1690. 正答率(テスト) = 0.1135
# Generation: 1700. 正答率(トレーニング) = 0.1
#                 : 1700. 正答率(テスト) = 0.1135
# Generation: 1710. 正答率(トレーニング) = 0.11
#                 : 1710. 正答率(テスト) = 0.0958
# Generation: 1720. 正答率(トレーニング) = 0.09
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.11
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.11
#                 : 1740. 正答率(テスト) = 0.101
# Generation: 1750. 正答率(トレーニング) = 0.09
#                 : 1750. 正答率(テスト) = 0.1028
# Generation: 1760. 正答率(トレーニング) = 0.1
#                 : 1760. 正答率(テスト) = 0.1028
# Generation: 1770. 正答率(トレーニング) = 0.07
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.07
#                 : 1780. 正答率(テスト) = 0.101
# Generation: 1790. 正答率(トレーニング) = 0.12
#                 : 1790. 正答率(テスト) = 0.1135
# Generation: 1800. 正答率(トレーニング) = 0.14
#                 : 1800. 正答率(テスト) = 0.101
# Generation: 1810. 正答率(トレーニング) = 0.08
#                 : 1810. 正答率(テスト) = 0.101
# Generation: 1820. 正答率(トレーニング) = 0.12
#                 : 1820. 正答率(テスト) = 0.0958
# Generation: 1830. 正答率(トレーニング) = 0.11
#                 : 1830. 正答率(テスト) = 0.101
# Generation: 1840. 正答率(トレーニング) = 0.11
#                 : 1840. 正答率(テスト) = 0.0958
# Generation: 1850. 正答率(トレーニング) = 0.07
#                 : 1850. 正答率(テスト) = 0.1135
# Generation: 1860. 正答率(トレーニング) = 0.19
#                 : 1860. 正答率(テスト) = 0.1135
# Generation: 1870. 正答率(トレーニング) = 0.12
#                 : 1870. 正答率(テスト) = 0.1135
# Generation: 1880. 正答率(トレーニング) = 0.15
#                 : 1880. 正答率(テスト) = 0.1028
# Generation: 1890. 正答率(トレーニング) = 0.21
#                 : 1890. 正答率(テスト) = 0.1135
# Generation: 1900. 正答率(トレーニング) = 0.12
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.13
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.16
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.07
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.12
#                 : 1940. 正答率(テスト) = 0.1135
# Generation: 1950. 正答率(トレーニング) = 0.19
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.14
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.16
#                 : 1970. 正答率(テスト) = 0.1028
# Generation: 1980. 正答率(トレーニング) = 0.14
#                 : 1980. 正答率(テスト) = 0.1028
# Generation: 1990. 正答率(トレーニング) = 0.12
#                 : 1990. 正答率(テスト) = 0.1028
# Generation: 2000. 正答率(トレーニング) = 0.11
#                 : 2000. 正答率(テスト) = 0.1135

# %% [markdown]
# ## ReLU - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.08
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.04
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.06
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.06
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.1
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.08
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.09
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.08
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.1
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.1
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.07
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.12
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.08
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.13
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.12
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.14
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.12
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.12
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.1
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.07
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.14
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.08
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.12
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.11
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.11
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.11
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.09
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.1
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.12
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.12
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.08
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.06
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.14
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.12
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.16
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.07
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.07
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.07
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.1
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.16
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.15
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.11
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.1
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.26
#                 : 490. 正答率(テスト) = 0.1594
# Generation: 500. 正答率(トレーニング) = 0.21
#                 : 500. 正答率(テスト) = 0.2133
# Generation: 510. 正答率(トレーニング) = 0.15
#                 : 510. 正答率(テスト) = 0.2067
# Generation: 520. 正答率(トレーニング) = 0.17
#                 : 520. 正答率(テスト) = 0.2092
# Generation: 530. 正答率(トレーニング) = 0.24
#                 : 530. 正答率(テスト) = 0.2261
# Generation: 540. 正答率(トレーニング) = 0.29
#                 : 540. 正答率(テスト) = 0.1991
# Generation: 550. 正答率(トレーニング) = 0.32
#                 : 550. 正答率(テスト) = 0.2121
# Generation: 560. 正答率(トレーニング) = 0.21
#                 : 560. 正答率(テスト) = 0.2377
# Generation: 570. 正答率(トレーニング) = 0.32
#                 : 570. 正答率(テスト) = 0.244
# Generation: 580. 正答率(トレーニング) = 0.32
#                 : 580. 正答率(テスト) = 0.2634
# Generation: 590. 正答率(トレーニング) = 0.15
#                 : 590. 正答率(テスト) = 0.3033
# Generation: 600. 正答率(トレーニング) = 0.29
#                 : 600. 正答率(テスト) = 0.2828
# Generation: 610. 正答率(トレーニング) = 0.29
#                 : 610. 正答率(テスト) = 0.3109
# Generation: 620. 正答率(トレーニング) = 0.42
#                 : 620. 正答率(テスト) = 0.3046
# Generation: 630. 正答率(トレーニング) = 0.35
#                 : 630. 正答率(テスト) = 0.3196
# Generation: 640. 正答率(トレーニング) = 0.45
#                 : 640. 正答率(テスト) = 0.4361
# Generation: 650. 正答率(トレーニング) = 0.38
#                 : 650. 正答率(テスト) = 0.3393
# Generation: 660. 正答率(トレーニング) = 0.45
#                 : 660. 正答率(テスト) = 0.4322
# Generation: 670. 正答率(トレーニング) = 0.51
#                 : 670. 正答率(テスト) = 0.3752
# Generation: 680. 正答率(トレーニング) = 0.54
#                 : 680. 正答率(テスト) = 0.4205
# Generation: 690. 正答率(トレーニング) = 0.53
#                 : 690. 正答率(テスト) = 0.4702
# Generation: 700. 正答率(トレーニング) = 0.47
#                 : 700. 正答率(テスト) = 0.4817
# Generation: 710. 正答率(トレーニング) = 0.56
#                 : 710. 正答率(テスト) = 0.5071
# Generation: 720. 正答率(トレーニング) = 0.63
#                 : 720. 正答率(テスト) = 0.5933
# Generation: 730. 正答率(トレーニング) = 0.64
#                 : 730. 正答率(テスト) = 0.6261
# Generation: 740. 正答率(トレーニング) = 0.64
#                 : 740. 正答率(テスト) = 0.629
# Generation: 750. 正答率(トレーニング) = 0.65
#                 : 750. 正答率(テスト) = 0.622
# Generation: 760. 正答率(トレーニング) = 0.77
#                 : 760. 正答率(テスト) = 0.6487
# Generation: 770. 正答率(トレーニング) = 0.8
#                 : 770. 正答率(テスト) = 0.6921
# Generation: 780. 正答率(トレーニング) = 0.77
#                 : 780. 正答率(テスト) = 0.6554
# Generation: 790. 正答率(トレーニング) = 0.67
#                 : 790. 正答率(テスト) = 0.6864
# Generation: 800. 正答率(トレーニング) = 0.71
#                 : 800. 正答率(テスト) = 0.7085
# Generation: 810. 正答率(トレーニング) = 0.87
#                 : 810. 正答率(テスト) = 0.7246
# Generation: 820. 正答率(トレーニング) = 0.72
#                 : 820. 正答率(テスト) = 0.6652
# Generation: 830. 正答率(トレーニング) = 0.79
#                 : 830. 正答率(テスト) = 0.7353
# Generation: 840. 正答率(トレーニング) = 0.81
#                 : 840. 正答率(テスト) = 0.7699
# Generation: 850. 正答率(トレーニング) = 0.86
#                 : 850. 正答率(テスト) = 0.7545
# Generation: 860. 正答率(トレーニング) = 0.81
#                 : 860. 正答率(テスト) = 0.7615
# Generation: 870. 正答率(トレーニング) = 0.84
#                 : 870. 正答率(テスト) = 0.7607
# Generation: 880. 正答率(トレーニング) = 0.8
#                 : 880. 正答率(テスト) = 0.758
# Generation: 890. 正答率(トレーニング) = 0.8
#                 : 890. 正答率(テスト) = 0.7126
# Generation: 900. 正答率(トレーニング) = 0.88
#                 : 900. 正答率(テスト) = 0.7733
# Generation: 910. 正答率(トレーニング) = 0.82
#                 : 910. 正答率(テスト) = 0.783
# Generation: 920. 正答率(トレーニング) = 0.79
#                 : 920. 正答率(テスト) = 0.794
# Generation: 930. 正答率(トレーニング) = 0.81
#                 : 930. 正答率(テスト) = 0.7888
# Generation: 940. 正答率(トレーニング) = 0.84
#                 : 940. 正答率(テスト) = 0.797
# Generation: 950. 正答率(トレーニング) = 0.82
#                 : 950. 正答率(テスト) = 0.8168
# Generation: 960. 正答率(トレーニング) = 0.87
#                 : 960. 正答率(テスト) = 0.8002
# Generation: 970. 正答率(トレーニング) = 0.89
#                 : 970. 正答率(テスト) = 0.8263
# Generation: 980. 正答率(トレーニング) = 0.89
#                 : 980. 正答率(テスト) = 0.8131
# Generation: 990. 正答率(トレーニング) = 0.8
#                 : 990. 正答率(テスト) = 0.8344
# Generation: 1000. 正答率(トレーニング) = 0.87
#                 : 1000. 正答率(テスト) = 0.8171
# Generation: 1010. 正答率(トレーニング) = 0.86
#                 : 1010. 正答率(テスト) = 0.8374
# Generation: 1020. 正答率(トレーニング) = 0.93
#                 : 1020. 正答率(テスト) = 0.8348
# Generation: 1030. 正答率(トレーニング) = 0.83
#                 : 1030. 正答率(テスト) = 0.8355
# Generation: 1040. 正答率(トレーニング) = 0.9
#                 : 1040. 正答率(テスト) = 0.8368
# Generation: 1050. 正答率(トレーニング) = 0.85
#                 : 1050. 正答率(テスト) = 0.8364
# Generation: 1060. 正答率(トレーニング) = 0.94
#                 : 1060. 正答率(テスト) = 0.8448
# Generation: 1070. 正答率(トレーニング) = 0.86
#                 : 1070. 正答率(テスト) = 0.81
# Generation: 1080. 正答率(トレーニング) = 0.92
#                 : 1080. 正答率(テスト) = 0.8445
# Generation: 1090. 正答率(トレーニング) = 0.85
#                 : 1090. 正答率(テスト) = 0.8482
# Generation: 1100. 正答率(トレーニング) = 0.87
#                 : 1100. 正答率(テスト) = 0.8509
# Generation: 1110. 正答率(トレーニング) = 0.92
#                 : 1110. 正答率(テスト) = 0.8457
# Generation: 1120. 正答率(トレーニング) = 0.84
#                 : 1120. 正答率(テスト) = 0.837
# Generation: 1130. 正答率(トレーニング) = 0.85
#                 : 1130. 正答率(テスト) = 0.8479
# Generation: 1140. 正答率(トレーニング) = 0.87
#                 : 1140. 正答率(テスト) = 0.8572
# Generation: 1150. 正答率(トレーニング) = 0.81
#                 : 1150. 正答率(テスト) = 0.863
# Generation: 1160. 正答率(トレーニング) = 0.87
#                 : 1160. 正答率(テスト) = 0.8601
# Generation: 1170. 正答率(トレーニング) = 0.88
#                 : 1170. 正答率(テスト) = 0.8667
# Generation: 1180. 正答率(トレーニング) = 0.86
#                 : 1180. 正答率(テスト) = 0.8512
# Generation: 1190. 正答率(トレーニング) = 0.93
#                 : 1190. 正答率(テスト) = 0.8645
# Generation: 1200. 正答率(トレーニング) = 0.9
#                 : 1200. 正答率(テスト) = 0.8656
# Generation: 1210. 正答率(トレーニング) = 0.91
#                 : 1210. 正答率(テスト) = 0.8577
# Generation: 1220. 正答率(トレーニング) = 0.9
#                 : 1220. 正答率(テスト) = 0.8713
# Generation: 1230. 正答率(トレーニング) = 0.93
#                 : 1230. 正答率(テスト) = 0.8712
# Generation: 1240. 正答率(トレーニング) = 0.86
#                 : 1240. 正答率(テスト) = 0.862
# Generation: 1250. 正答率(トレーニング) = 0.87
#                 : 1250. 正答率(テスト) = 0.8762
# Generation: 1260. 正答率(トレーニング) = 0.95
#                 : 1260. 正答率(テスト) = 0.8763
# Generation: 1270. 正答率(トレーニング) = 0.92
#                 : 1270. 正答率(テスト) = 0.8738
# Generation: 1280. 正答率(トレーニング) = 0.9
#                 : 1280. 正答率(テスト) = 0.8842
# Generation: 1290. 正答率(トレーニング) = 0.93
#                 : 1290. 正答率(テスト) = 0.8858
# Generation: 1300. 正答率(トレーニング) = 0.86
#                 : 1300. 正答率(テスト) = 0.8611
# Generation: 1310. 正答率(トレーニング) = 0.9
#                 : 1310. 正答率(テスト) = 0.886
# Generation: 1320. 正答率(トレーニング) = 0.89
#                 : 1320. 正答率(テスト) = 0.8741
# Generation: 1330. 正答率(トレーニング) = 0.93
#                 : 1330. 正答率(テスト) = 0.8898
# Generation: 1340. 正答率(トレーニング) = 0.9
#                 : 1340. 正答率(テスト) = 0.8906
# Generation: 1350. 正答率(トレーニング) = 0.91
#                 : 1350. 正答率(テスト) = 0.8826
# Generation: 1360. 正答率(トレーニング) = 0.88
#                 : 1360. 正答率(テスト) = 0.8902
# Generation: 1370. 正答率(トレーニング) = 0.92
#                 : 1370. 正答率(テスト) = 0.8915
# Generation: 1380. 正答率(トレーニング) = 0.9
#                 : 1380. 正答率(テスト) = 0.8889
# Generation: 1390. 正答率(トレーニング) = 0.93
#                 : 1390. 正答率(テスト) = 0.8918
# Generation: 1400. 正答率(トレーニング) = 0.84
#                 : 1400. 正答率(テスト) = 0.8916
# Generation: 1410. 正答率(トレーニング) = 0.97
#                 : 1410. 正答率(テスト) = 0.8948
# Generation: 1420. 正答率(トレーニング) = 0.95
#                 : 1420. 正答率(テスト) = 0.8931
# Generation: 1430. 正答率(トレーニング) = 0.93
#                 : 1430. 正答率(テスト) = 0.8933
# Generation: 1440. 正答率(トレーニング) = 0.94
#                 : 1440. 正答率(テスト) = 0.8993
# Generation: 1450. 正答率(トレーニング) = 0.91
#                 : 1450. 正答率(テスト) = 0.8884
# Generation: 1460. 正答率(トレーニング) = 0.92
#                 : 1460. 正答率(テスト) = 0.8948
# Generation: 1470. 正答率(トレーニング) = 0.88
#                 : 1470. 正答率(テスト) = 0.8975
# Generation: 1480. 正答率(トレーニング) = 0.9
#                 : 1480. 正答率(テスト) = 0.8977
# Generation: 1490. 正答率(トレーニング) = 0.9
#                 : 1490. 正答率(テスト) = 0.9013
# Generation: 1500. 正答率(トレーニング) = 0.93
#                 : 1500. 正答率(テスト) = 0.8889
# Generation: 1510. 正答率(トレーニング) = 0.93
#                 : 1510. 正答率(テスト) = 0.8996
# Generation: 1520. 正答率(トレーニング) = 0.93
#                 : 1520. 正答率(テスト) = 0.9008
# Generation: 1530. 正答率(トレーニング) = 0.94
#                 : 1530. 正答率(テスト) = 0.9064
# Generation: 1540. 正答率(トレーニング) = 0.91
#                 : 1540. 正答率(テスト) = 0.8962
# Generation: 1550. 正答率(トレーニング) = 0.93
#                 : 1550. 正答率(テスト) = 0.9071
# Generation: 1560. 正答率(トレーニング) = 0.97
#                 : 1560. 正答率(テスト) = 0.8975
# Generation: 1570. 正答率(トレーニング) = 0.9
#                 : 1570. 正答率(テスト) = 0.9037
# Generation: 1580. 正答率(トレーニング) = 0.95
#                 : 1580. 正答率(テスト) = 0.8963
# Generation: 1590. 正答率(トレーニング) = 0.97
#                 : 1590. 正答率(テスト) = 0.901
# Generation: 1600. 正答率(トレーニング) = 0.95
#                 : 1600. 正答率(テスト) = 0.9113
# Generation: 1610. 正答率(トレーニング) = 0.94
#                 : 1610. 正答率(テスト) = 0.9092
# Generation: 1620. 正答率(トレーニング) = 0.92
#                 : 1620. 正答率(テスト) = 0.9111
# Generation: 1630. 正答率(トレーニング) = 0.98
#                 : 1630. 正答率(テスト) = 0.9085
# Generation: 1640. 正答率(トレーニング) = 0.98
#                 : 1640. 正答率(テスト) = 0.9114
# Generation: 1650. 正答率(トレーニング) = 0.88
#                 : 1650. 正答率(テスト) = 0.9067
# Generation: 1660. 正答率(トレーニング) = 0.87
#                 : 1660. 正答率(テスト) = 0.909
# Generation: 1670. 正答率(トレーニング) = 0.94
#                 : 1670. 正答率(テスト) = 0.9139
# Generation: 1680. 正答率(トレーニング) = 0.91
#                 : 1680. 正答率(テスト) = 0.913
# Generation: 1690. 正答率(トレーニング) = 0.94
#                 : 1690. 正答率(テスト) = 0.9068
# Generation: 1700. 正答率(トレーニング) = 0.93
#                 : 1700. 正答率(テスト) = 0.9101
# Generation: 1710. 正答率(トレーニング) = 0.95
#                 : 1710. 正答率(テスト) = 0.9165
# Generation: 1720. 正答率(トレーニング) = 0.93
#                 : 1720. 正答率(テスト) = 0.9163
# Generation: 1730. 正答率(トレーニング) = 1.0
#                 : 1730. 正答率(テスト) = 0.914
# Generation: 1740. 正答率(トレーニング) = 0.95
#                 : 1740. 正答率(テスト) = 0.9084
# Generation: 1750. 正答率(トレーニング) = 0.89
#                 : 1750. 正答率(テスト) = 0.9104
# Generation: 1760. 正答率(トレーニング) = 0.94
#                 : 1760. 正答率(テスト) = 0.9157
# Generation: 1770. 正答率(トレーニング) = 0.99
#                 : 1770. 正答率(テスト) = 0.9191
# Generation: 1780. 正答率(トレーニング) = 0.91
#                 : 1780. 正答率(テスト) = 0.914
# Generation: 1790. 正答率(トレーニング) = 0.95
#                 : 1790. 正答率(テスト) = 0.9204
# Generation: 1800. 正答率(トレーニング) = 0.94
#                 : 1800. 正答率(テスト) = 0.9125
# Generation: 1810. 正答率(トレーニング) = 0.96
#                 : 1810. 正答率(テスト) = 0.9208
# Generation: 1820. 正答率(トレーニング) = 0.98
#                 : 1820. 正答率(テスト) = 0.9216
# Generation: 1830. 正答率(トレーニング) = 0.95
#                 : 1830. 正答率(テスト) = 0.9193
# Generation: 1840. 正答率(トレーニング) = 0.97
#                 : 1840. 正答率(テスト) = 0.9177
# Generation: 1850. 正答率(トレーニング) = 0.92
#                 : 1850. 正答率(テスト) = 0.9206
# Generation: 1860. 正答率(トレーニング) = 0.93
#                 : 1860. 正答率(テスト) = 0.9145
# Generation: 1870. 正答率(トレーニング) = 0.96
#                 : 1870. 正答率(テスト) = 0.9232
# Generation: 1880. 正答率(トレーニング) = 0.94
#                 : 1880. 正答率(テスト) = 0.9219
# Generation: 1890. 正答率(トレーニング) = 0.97
#                 : 1890. 正答率(テスト) = 0.9242
# Generation: 1900. 正答率(トレーニング) = 0.96
#                 : 1900. 正答率(テスト) = 0.9232
# Generation: 1910. 正答率(トレーニング) = 0.93
#                 : 1910. 正答率(テスト) = 0.926
# Generation: 1920. 正答率(トレーニング) = 0.97
#                 : 1920. 正答率(テスト) = 0.9166
# Generation: 1930. 正答率(トレーニング) = 0.95
#                 : 1930. 正答率(テスト) = 0.9214
# Generation: 1940. 正答率(トレーニング) = 0.92
#                 : 1940. 正答率(テスト) = 0.9251
# Generation: 1950. 正答率(トレーニング) = 0.93
#                 : 1950. 正答率(テスト) = 0.9189
# Generation: 1960. 正答率(トレーニング) = 0.9
#                 : 1960. 正答率(テスト) = 0.9278
# Generation: 1970. 正答率(トレーニング) = 0.94
#                 : 1970. 正答率(テスト) = 0.9234
# Generation: 1980. 正答率(トレーニング) = 0.97
#                 : 1980. 正答率(テスト) = 0.9107
# Generation: 1990. 正答率(トレーニング) = 0.94
#                 : 1990. 正答率(テスト) = 0.9254
# Generation: 2000. 正答率(トレーニング) = 0.91
#                 : 2000. 正答率(テスト) = 0.9271

# %% [markdown]
# ## sigmoid - Xavier

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std='Xavier')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15
#                 : 10. 正答率(テスト) = 0.099
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1031
# Generation: 30. 正答率(トレーニング) = 0.16
#                 : 30. 正答率(テスト) = 0.1337
# Generation: 40. 正答率(トレーニング) = 0.17
#                 : 40. 正答率(テスト) = 0.1042
# Generation: 50. 正答率(トレーニング) = 0.19
#                 : 50. 正答率(テスト) = 0.1801
# Generation: 60. 正答率(トレーニング) = 0.21
#                 : 60. 正答率(テスト) = 0.2443
# Generation: 70. 正答率(トレーニング) = 0.19
#                 : 70. 正答率(テスト) = 0.2007
# Generation: 80. 正答率(トレーニング) = 0.25
#                 : 80. 正答率(テスト) = 0.2984
# Generation: 90. 正答率(トレーニング) = 0.35
#                 : 90. 正答率(テスト) = 0.3684
# Generation: 100. 正答率(トレーニング) = 0.43
#                 : 100. 正答率(テスト) = 0.3058
# Generation: 110. 正答率(トレーニング) = 0.38
#                 : 110. 正答率(テスト) = 0.4102
# Generation: 120. 正答率(トレーニング) = 0.27
#                 : 120. 正答率(テスト) = 0.2326
# Generation: 130. 正答率(トレーニング) = 0.33
#                 : 130. 正答率(テスト) = 0.3995
# Generation: 140. 正答率(トレーニング) = 0.56
#                 : 140. 正答率(テスト) = 0.4462
# Generation: 150. 正答率(トレーニング) = 0.3
#                 : 150. 正答率(テスト) = 0.2903
# Generation: 160. 正答率(トレーニング) = 0.31
#                 : 160. 正答率(テスト) = 0.3185
# Generation: 170. 正答率(トレーニング) = 0.33
#                 : 170. 正答率(テスト) = 0.3295
# Generation: 180. 正答率(トレーニング) = 0.46
#                 : 180. 正答率(テスト) = 0.4844
# Generation: 190. 正答率(トレーニング) = 0.51
#                 : 190. 正答率(テスト) = 0.5269
# Generation: 200. 正答率(トレーニング) = 0.57
#                 : 200. 正答率(テスト) = 0.5473
# Generation: 210. 正答率(トレーニング) = 0.46
#                 : 210. 正答率(テスト) = 0.4404
# Generation: 220. 正答率(トレーニング) = 0.52
#                 : 220. 正答率(テスト) = 0.4589
# Generation: 230. 正答率(トレーニング) = 0.36
#                 : 230. 正答率(テスト) = 0.4251
# Generation: 240. 正答率(トレーニング) = 0.41
#                 : 240. 正答率(テスト) = 0.4869
# Generation: 250. 正答率(トレーニング) = 0.56
#                 : 250. 正答率(テスト) = 0.5131
# Generation: 260. 正答率(トレーニング) = 0.49
#                 : 260. 正答率(テスト) = 0.4561
# Generation: 270. 正答率(トレーニング) = 0.47
#                 : 270. 正答率(テスト) = 0.4317
# Generation: 280. 正答率(トレーニング) = 0.49
#                 : 280. 正答率(テスト) = 0.4336
# Generation: 290. 正答率(トレーニング) = 0.48
#                 : 290. 正答率(テスト) = 0.4342
# Generation: 300. 正答率(トレーニング) = 0.47
#                 : 300. 正答率(テスト) = 0.4513
# Generation: 310. 正答率(トレーニング) = 0.45
#                 : 310. 正答率(テスト) = 0.4079
# Generation: 320. 正答率(トレーニング) = 0.5
#                 : 320. 正答率(テスト) = 0.4713
# Generation: 330. 正答率(トレーニング) = 0.55
#                 : 330. 正答率(テスト) = 0.5053
# Generation: 340. 正答率(トレーニング) = 0.48
#                 : 340. 正答率(テスト) = 0.442
# Generation: 350. 正答率(トレーニング) = 0.43
#                 : 350. 正答率(テスト) = 0.4797
# Generation: 360. 正答率(トレーニング) = 0.58
#                 : 360. 正答率(テスト) = 0.4874
# Generation: 370. 正答率(トレーニング) = 0.57
#                 : 370. 正答率(テスト) = 0.4658
# Generation: 380. 正答率(トレーニング) = 0.42
#                 : 380. 正答率(テスト) = 0.4825
# Generation: 390. 正答率(トレーニング) = 0.5
#                 : 390. 正答率(テスト) = 0.4659
# Generation: 400. 正答率(トレーニング) = 0.45
#                 : 400. 正答率(テスト) = 0.508
# Generation: 410. 正答率(トレーニング) = 0.53
#                 : 410. 正答率(テスト) = 0.4821
# Generation: 420. 正答率(トレーニング) = 0.52
#                 : 420. 正答率(テスト) = 0.5273
# Generation: 430. 正答率(トレーニング) = 0.54
#                 : 430. 正答率(テスト) = 0.5322
# Generation: 440. 正答率(トレーニング) = 0.44
#                 : 440. 正答率(テスト) = 0.5507
# Generation: 450. 正答率(トレーニング) = 0.67
#                 : 450. 正答率(テスト) = 0.5673
# Generation: 460. 正答率(トレーニング) = 0.58
#                 : 460. 正答率(テスト) = 0.562
# Generation: 470. 正答率(トレーニング) = 0.55
#                 : 470. 正答率(テスト) = 0.5527
# Generation: 480. 正答率(トレーニング) = 0.62
#                 : 480. 正答率(テスト) = 0.574
# Generation: 490. 正答率(トレーニング) = 0.63
#                 : 490. 正答率(テスト) = 0.5708
# Generation: 500. 正答率(トレーニング) = 0.58
#                 : 500. 正答率(テスト) = 0.5865
# Generation: 510. 正答率(トレーニング) = 0.65
#                 : 510. 正答率(テスト) = 0.6087
# Generation: 520. 正答率(トレーニング) = 0.54
#                 : 520. 正答率(テスト) = 0.6044
# Generation: 530. 正答率(トレーニング) = 0.63
#                 : 530. 正答率(テスト) = 0.6067
# Generation: 540. 正答率(トレーニング) = 0.64
#                 : 540. 正答率(テスト) = 0.6184
# Generation: 550. 正答率(トレーニング) = 0.66
#                 : 550. 正答率(テスト) = 0.6203
# Generation: 560. 正答率(トレーニング) = 0.68
#                 : 560. 正答率(テスト) = 0.6286
# Generation: 570. 正答率(トレーニング) = 0.61
#                 : 570. 正答率(テスト) = 0.6364
# Generation: 580. 正答率(トレーニング) = 0.64
#                 : 580. 正答率(テスト) = 0.6491
# Generation: 590. 正答率(トレーニング) = 0.58
#                 : 590. 正答率(テスト) = 0.6434
# Generation: 600. 正答率(トレーニング) = 0.65
#                 : 600. 正答率(テスト) = 0.6547
# Generation: 610. 正答率(トレーニング) = 0.63
#                 : 610. 正答率(テスト) = 0.655
# Generation: 620. 正答率(トレーニング) = 0.67
#                 : 620. 正答率(テスト) = 0.6702
# Generation: 630. 正答率(トレーニング) = 0.63
#                 : 630. 正答率(テスト) = 0.6842
# Generation: 640. 正答率(トレーニング) = 0.64
#                 : 640. 正答率(テスト) = 0.6917
# Generation: 650. 正答率(トレーニング) = 0.73
#                 : 650. 正答率(テスト) = 0.6816
# Generation: 660. 正答率(トレーニング) = 0.69
#                 : 660. 正答率(テスト) = 0.6896
# Generation: 670. 正答率(トレーニング) = 0.74
#                 : 670. 正答率(テスト) = 0.6888
# Generation: 680. 正答率(トレーニング) = 0.72
#                 : 680. 正答率(テスト) = 0.6765
# Generation: 690. 正答率(トレーニング) = 0.61
#                 : 690. 正答率(テスト) = 0.7007
# Generation: 700. 正答率(トレーニング) = 0.78
#                 : 700. 正答率(テスト) = 0.7091
# Generation: 710. 正答率(トレーニング) = 0.7
#                 : 710. 正答率(テスト) = 0.7068
# Generation: 720. 正答率(トレーニング) = 0.8
#                 : 720. 正答率(テスト) = 0.6988
# Generation: 730. 正答率(トレーニング) = 0.72
#                 : 730. 正答率(テスト) = 0.6985
# Generation: 740. 正答率(トレーニング) = 0.72
#                 : 740. 正答率(テスト) = 0.7207
# Generation: 750. 正答率(トレーニング) = 0.74
#                 : 750. 正答率(テスト) = 0.7069
# Generation: 760. 正答率(トレーニング) = 0.75
#                 : 760. 正答率(テスト) = 0.7119
# Generation: 770. 正答率(トレーニング) = 0.77
#                 : 770. 正答率(テスト) = 0.7234
# Generation: 780. 正答率(トレーニング) = 0.8
#                 : 780. 正答率(テスト) = 0.7216
# Generation: 790. 正答率(トレーニング) = 0.77
#                 : 790. 正答率(テスト) = 0.7222
# Generation: 800. 正答率(トレーニング) = 0.74
#                 : 800. 正答率(テスト) = 0.7299
# Generation: 810. 正答率(トレーニング) = 0.69
#                 : 810. 正答率(テスト) = 0.7414
# Generation: 820. 正答率(トレーニング) = 0.67
#                 : 820. 正答率(テスト) = 0.7407
# Generation: 830. 正答率(トレーニング) = 0.7
#                 : 830. 正答率(テスト) = 0.7363
# Generation: 840. 正答率(トレーニング) = 0.81
#                 : 840. 正答率(テスト) = 0.7434
# Generation: 850. 正答率(トレーニング) = 0.74
#                 : 850. 正答率(テスト) = 0.7458
# Generation: 860. 正答率(トレーニング) = 0.7
#                 : 860. 正答率(テスト) = 0.7477
# Generation: 870. 正答率(トレーニング) = 0.73
#                 : 870. 正答率(テスト) = 0.7491
# Generation: 880. 正答率(トレーニング) = 0.79
#                 : 880. 正答率(テスト) = 0.7513
# Generation: 890. 正答率(トレーニング) = 0.75
#                 : 890. 正答率(テスト) = 0.7543
# Generation: 900. 正答率(トレーニング) = 0.75
#                 : 900. 正答率(テスト) = 0.7559
# Generation: 910. 正答率(トレーニング) = 0.75
#                 : 910. 正答率(テスト) = 0.7555
# Generation: 920. 正答率(トレーニング) = 0.75
#                 : 920. 正答率(テスト) = 0.7671
# Generation: 930. 正答率(トレーニング) = 0.77
#                 : 930. 正答率(テスト) = 0.7557
# Generation: 940. 正答率(トレーニング) = 0.75
#                 : 940. 正答率(テスト) = 0.7555
# Generation: 950. 正答率(トレーニング) = 0.74
#                 : 950. 正答率(テスト) = 0.7625
# Generation: 960. 正答率(トレーニング) = 0.82
#                 : 960. 正答率(テスト) = 0.7549
# Generation: 970. 正答率(トレーニング) = 0.77
#                 : 970. 正答率(テスト) = 0.7581
# Generation: 980. 正答率(トレーニング) = 0.74
#                 : 980. 正答率(テスト) = 0.7691
# Generation: 990. 正答率(トレーニング) = 0.72
#                 : 990. 正答率(テスト) = 0.7809
# Generation: 1000. 正答率(トレーニング) = 0.78
#                 : 1000. 正答率(テスト) = 0.7734
# Generation: 1010. 正答率(トレーニング) = 0.82
#                 : 1010. 正答率(テスト) = 0.7785
# Generation: 1020. 正答率(トレーニング) = 0.81
#                 : 1020. 正答率(テスト) = 0.7822
# Generation: 1030. 正答率(トレーニング) = 0.78
#                 : 1030. 正答率(テスト) = 0.7738
# Generation: 1040. 正答率(トレーニング) = 0.79
#                 : 1040. 正答率(テスト) = 0.7745
# Generation: 1050. 正答率(トレーニング) = 0.71
#                 : 1050. 正答率(テスト) = 0.7694
# Generation: 1060. 正答率(トレーニング) = 0.77
#                 : 1060. 正答率(テスト) = 0.7772
# Generation: 1070. 正答率(トレーニング) = 0.77
#                 : 1070. 正答率(テスト) = 0.7826
# Generation: 1080. 正答率(トレーニング) = 0.7
#                 : 1080. 正答率(テスト) = 0.7835
# Generation: 1090. 正答率(トレーニング) = 0.72
#                 : 1090. 正答率(テスト) = 0.7899
# Generation: 1100. 正答率(トレーニング) = 0.8
#                 : 1100. 正答率(テスト) = 0.7885
# Generation: 1110. 正答率(トレーニング) = 0.74
#                 : 1110. 正答率(テスト) = 0.7887
# Generation: 1120. 正答率(トレーニング) = 0.8
#                 : 1120. 正答率(テスト) = 0.7944
# Generation: 1130. 正答率(トレーニング) = 0.83
#                 : 1130. 正答率(テスト) = 0.7939
# Generation: 1140. 正答率(トレーニング) = 0.8
#                 : 1140. 正答率(テスト) = 0.797
# Generation: 1150. 正答率(トレーニング) = 0.78
#                 : 1150. 正答率(テスト) = 0.7968
# Generation: 1160. 正答率(トレーニング) = 0.79
#                 : 1160. 正答率(テスト) = 0.8019
# Generation: 1170. 正答率(トレーニング) = 0.79
#                 : 1170. 正答率(テスト) = 0.7985
# Generation: 1180. 正答率(トレーニング) = 0.75
#                 : 1180. 正答率(テスト) = 0.8036
# Generation: 1190. 正答率(トレーニング) = 0.86
#                 : 1190. 正答率(テスト) = 0.807
# Generation: 1200. 正答率(トレーニング) = 0.83
#                 : 1200. 正答率(テスト) = 0.8055
# Generation: 1210. 正答率(トレーニング) = 0.79
#                 : 1210. 正答率(テスト) = 0.806
# Generation: 1220. 正答率(トレーニング) = 0.83
#                 : 1220. 正答率(テスト) = 0.8086
# Generation: 1230. 正答率(トレーニング) = 0.81
#                 : 1230. 正答率(テスト) = 0.8075
# Generation: 1240. 正答率(トレーニング) = 0.81
#                 : 1240. 正答率(テスト) = 0.8104
# Generation: 1250. 正答率(トレーニング) = 0.84
#                 : 1250. 正答率(テスト) = 0.8108
# Generation: 1260. 正答率(トレーニング) = 0.84
#                 : 1260. 正答率(テスト) = 0.8125
# Generation: 1270. 正答率(トレーニング) = 0.82
#                 : 1270. 正答率(テスト) = 0.8162
# Generation: 1280. 正答率(トレーニング) = 0.81
#                 : 1280. 正答率(テスト) = 0.8197
# Generation: 1290. 正答率(トレーニング) = 0.79
#                 : 1290. 正答率(テスト) = 0.8204
# Generation: 1300. 正答率(トレーニング) = 0.78
#                 : 1300. 正答率(テスト) = 0.8206
# Generation: 1310. 正答率(トレーニング) = 0.8
#                 : 1310. 正答率(テスト) = 0.8156
# Generation: 1320. 正答率(トレーニング) = 0.81
#                 : 1320. 正答率(テスト) = 0.8223
# Generation: 1330. 正答率(トレーニング) = 0.83
#                 : 1330. 正答率(テスト) = 0.8246
# Generation: 1340. 正答率(トレーニング) = 0.85
#                 : 1340. 正答率(テスト) = 0.8239
# Generation: 1350. 正答率(トレーニング) = 0.77
#                 : 1350. 正答率(テスト) = 0.8233
# Generation: 1360. 正答率(トレーニング) = 0.74
#                 : 1360. 正答率(テスト) = 0.827
# Generation: 1370. 正答率(トレーニング) = 0.81
#                 : 1370. 正答率(テスト) = 0.8299
# Generation: 1380. 正答率(トレーニング) = 0.88
#                 : 1380. 正答率(テスト) = 0.8249
# Generation: 1390. 正答率(トレーニング) = 0.91
#                 : 1390. 正答率(テスト) = 0.833
# Generation: 1400. 正答率(トレーニング) = 0.87
#                 : 1400. 正答率(テスト) = 0.8274
# Generation: 1410. 正答率(トレーニング) = 0.85
#                 : 1410. 正答率(テスト) = 0.8331
# Generation: 1420. 正答率(トレーニング) = 0.78
#                 : 1420. 正答率(テスト) = 0.8344
# Generation: 1430. 正答率(トレーニング) = 0.78
#                 : 1430. 正答率(テスト) = 0.8364
# Generation: 1440. 正答率(トレーニング) = 0.84
#                 : 1440. 正答率(テスト) = 0.8373
# Generation: 1450. 正答率(トレーニング) = 0.81
#                 : 1450. 正答率(テスト) = 0.8399
# Generation: 1460. 正答率(トレーニング) = 0.85
#                 : 1460. 正答率(テスト) = 0.8388
# Generation: 1470. 正答率(トレーニング) = 0.8
#                 : 1470. 正答率(テスト) = 0.8415
# Generation: 1480. 正答率(トレーニング) = 0.82
#                 : 1480. 正答率(テスト) = 0.8424
# Generation: 1490. 正答率(トレーニング) = 0.82
#                 : 1490. 正答率(テスト) = 0.8417
# Generation: 1500. 正答率(トレーニング) = 0.83
#                 : 1500. 正答率(テスト) = 0.8433
# Generation: 1510. 正答率(トレーニング) = 0.87
#                 : 1510. 正答率(テスト) = 0.8399
# Generation: 1520. 正答率(トレーニング) = 0.88
#                 : 1520. 正答率(テスト) = 0.8442
# Generation: 1530. 正答率(トレーニング) = 0.85
#                 : 1530. 正答率(テスト) = 0.8467
# Generation: 1540. 正答率(トレーニング) = 0.86
#                 : 1540. 正答率(テスト) = 0.8478
# Generation: 1550. 正答率(トレーニング) = 0.83
#                 : 1550. 正答率(テスト) = 0.8468
# Generation: 1560. 正答率(トレーニング) = 0.84
#                 : 1560. 正答率(テスト) = 0.8495
# Generation: 1570. 正答率(トレーニング) = 0.8
#                 : 1570. 正答率(テスト) = 0.8496
# Generation: 1580. 正答率(トレーニング) = 0.88
#                 : 1580. 正答率(テスト) = 0.8514
# Generation: 1590. 正答率(トレーニング) = 0.9
#                 : 1590. 正答率(テスト) = 0.8511
# Generation: 1600. 正答率(トレーニング) = 0.89
#                 : 1600. 正答率(テスト) = 0.8503
# Generation: 1610. 正答率(トレーニング) = 0.85
#                 : 1610. 正答率(テスト) = 0.8488
# Generation: 1620. 正答率(トレーニング) = 0.82
#                 : 1620. 正答率(テスト) = 0.8477
# Generation: 1630. 正答率(トレーニング) = 0.82
#                 : 1630. 正答率(テスト) = 0.8528
# Generation: 1640. 正答率(トレーニング) = 0.87
#                 : 1640. 正答率(テスト) = 0.8565
# Generation: 1650. 正答率(トレーニング) = 0.88
#                 : 1650. 正答率(テスト) = 0.8509
# Generation: 1660. 正答率(トレーニング) = 0.83
#                 : 1660. 正答率(テスト) = 0.8549
# Generation: 1670. 正答率(トレーニング) = 0.85
#                 : 1670. 正答率(テスト) = 0.8567
# Generation: 1680. 正答率(トレーニング) = 0.82
#                 : 1680. 正答率(テスト) = 0.8587
# Generation: 1690. 正答率(トレーニング) = 0.87
#                 : 1690. 正答率(テスト) = 0.8578
# Generation: 1700. 正答率(トレーニング) = 0.84
#                 : 1700. 正答率(テスト) = 0.8588
# Generation: 1710. 正答率(トレーニング) = 0.8
#                 : 1710. 正答率(テスト) = 0.8603
# Generation: 1720. 正答率(トレーニング) = 0.8
#                 : 1720. 正答率(テスト) = 0.8596
# Generation: 1730. 正答率(トレーニング) = 0.86
#                 : 1730. 正答率(テスト) = 0.8597
# Generation: 1740. 正答率(トレーニング) = 0.86
#                 : 1740. 正答率(テスト) = 0.8615
# Generation: 1750. 正答率(トレーニング) = 0.86
#                 : 1750. 正答率(テスト) = 0.861
# Generation: 1760. 正答率(トレーニング) = 0.85
#                 : 1760. 正答率(テスト) = 0.8602
# Generation: 1770. 正答率(トレーニング) = 0.81
#                 : 1770. 正答率(テスト) = 0.8649
# Generation: 1780. 正答率(トレーニング) = 0.91
#                 : 1780. 正答率(テスト) = 0.8597
# Generation: 1790. 正答率(トレーニング) = 0.79
#                 : 1790. 正答率(テスト) = 0.8636
# Generation: 1800. 正答率(トレーニング) = 0.86
#                 : 1800. 正答率(テスト) = 0.8641
# Generation: 1810. 正答率(トレーニング) = 0.84
#                 : 1810. 正答率(テスト) = 0.8634
# Generation: 1820. 正答率(トレーニング) = 0.92
#                 : 1820. 正答率(テスト) = 0.8642
# Generation: 1830. 正答率(トレーニング) = 0.89
#                 : 1830. 正答率(テスト) = 0.8669
# Generation: 1840. 正答率(トレーニング) = 0.88
#                 : 1840. 正答率(テスト) = 0.8653
# Generation: 1850. 正答率(トレーニング) = 0.89
#                 : 1850. 正答率(テスト) = 0.8677
# Generation: 1860. 正答率(トレーニング) = 0.79
#                 : 1860. 正答率(テスト) = 0.8685
# Generation: 1870. 正答率(トレーニング) = 0.89
#                 : 1870. 正答率(テスト) = 0.8691
# Generation: 1880. 正答率(トレーニング) = 0.93
#                 : 1880. 正答率(テスト) = 0.867
# Generation: 1890. 正答率(トレーニング) = 0.87
#                 : 1890. 正答率(テスト) = 0.8691
# Generation: 1900. 正答率(トレーニング) = 0.88
#                 : 1900. 正答率(テスト) = 0.8692
# Generation: 1910. 正答率(トレーニング) = 0.87
#                 : 1910. 正答率(テスト) = 0.8687
# Generation: 1920. 正答率(トレーニング) = 0.82
#                 : 1920. 正答率(テスト) = 0.8696
# Generation: 1930. 正答率(トレーニング) = 0.88
#                 : 1930. 正答率(テスト) = 0.8705
# Generation: 1940. 正答率(トレーニング) = 0.89
#                 : 1940. 正答率(テスト) = 0.8683
# Generation: 1950. 正答率(トレーニング) = 0.85
#                 : 1950. 正答率(テスト) = 0.8703
# Generation: 1960. 正答率(トレーニング) = 0.84
#                 : 1960. 正答率(テスト) = 0.8714
# Generation: 1970. 正答率(トレーニング) = 0.9
#                 : 1970. 正答率(テスト) = 0.8728
# Generation: 1980. 正答率(トレーニング) = 0.87
#                 : 1980. 正答率(テスト) = 0.8731
# Generation: 1990. 正答率(トレーニング) = 0.85
#                 : 1990. 正答率(テスト) = 0.8728
# Generation: 2000. 正答率(トレーニング) = 0.85
#                 : 2000. 正答率(テスト) = 0.8737

# %% [markdown]
# ## ReLU - He

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std='He')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.52
#                 : 10. 正答率(テスト) = 0.4298
# Generation: 20. 正答率(トレーニング) = 0.65
#                 : 20. 正答率(テスト) = 0.6196
# Generation: 30. 正答率(トレーニング) = 0.74
#                 : 30. 正答率(テスト) = 0.6924
# Generation: 40. 正答率(トレーニング) = 0.76
#                 : 40. 正答率(テスト) = 0.6995
# Generation: 50. 正答率(トレーニング) = 0.86
#                 : 50. 正答率(テスト) = 0.7925
# Generation: 60. 正答率(トレーニング) = 0.88
#                 : 60. 正答率(テスト) = 0.8334
# Generation: 70. 正答率(トレーニング) = 0.84
#                 : 70. 正答率(テスト) = 0.8203
# Generation: 80. 正答率(トレーニング) = 0.88
#                 : 80. 正答率(テスト) = 0.8544
# Generation: 90. 正答率(トレーニング) = 0.93
#                 : 90. 正答率(テスト) = 0.8648
# Generation: 100. 正答率(トレーニング) = 0.84
#                 : 100. 正答率(テスト) = 0.8302
# Generation: 110. 正答率(トレーニング) = 0.93
#                 : 110. 正答率(テスト) = 0.8822
# Generation: 120. 正答率(トレーニング) = 0.88
#                 : 120. 正答率(テスト) = 0.8652
# Generation: 130. 正答率(トレーニング) = 0.95
#                 : 130. 正答率(テスト) = 0.8831
# Generation: 140. 正答率(トレーニング) = 0.91
#                 : 140. 正答率(テスト) = 0.8853
# Generation: 150. 正答率(トレーニング) = 0.95
#                 : 150. 正答率(テスト) = 0.886
# Generation: 160. 正答率(トレーニング) = 0.9
#                 : 160. 正答率(テスト) = 0.8774
# Generation: 170. 正答率(トレーニング) = 0.97
#                 : 170. 正答率(テスト) = 0.8975
# Generation: 180. 正答率(トレーニング) = 0.91
#                 : 180. 正答率(テスト) = 0.8938
# Generation: 190. 正答率(トレーニング) = 0.92
#                 : 190. 正答率(テスト) = 0.8884
# Generation: 200. 正答率(トレーニング) = 0.95
#                 : 200. 正答率(テスト) = 0.888
# Generation: 210. 正答率(トレーニング) = 0.9
#                 : 210. 正答率(テスト) = 0.8988
# Generation: 220. 正答率(トレーニング) = 0.83
#                 : 220. 正答率(テスト) = 0.8798
# Generation: 230. 正答率(トレーニング) = 0.93
#                 : 230. 正答率(テスト) = 0.9024
# Generation: 240. 正答率(トレーニング) = 0.89
#                 : 240. 正答率(テスト) = 0.9043
# Generation: 250. 正答率(トレーニング) = 0.91
#                 : 250. 正答率(テスト) = 0.9078
# Generation: 260. 正答率(トレーニング) = 0.91
#                 : 260. 正答率(テスト) = 0.9095
# Generation: 270. 正答率(トレーニング) = 0.94
#                 : 270. 正答率(テスト) = 0.9091
# Generation: 280. 正答率(トレーニング) = 0.95
#                 : 280. 正答率(テスト) = 0.9104
# Generation: 290. 正答率(トレーニング) = 0.93
#                 : 290. 正答率(テスト) = 0.9084
# Generation: 300. 正答率(トレーニング) = 0.93
#                 : 300. 正答率(テスト) = 0.9051
# Generation: 310. 正答率(トレーニング) = 0.97
#                 : 310. 正答率(テスト) = 0.9055
# Generation: 320. 正答率(トレーニング) = 0.95
#                 : 320. 正答率(テスト) = 0.8966
# Generation: 330. 正答率(トレーニング) = 0.88
#                 : 330. 正答率(テスト) = 0.8883
# Generation: 340. 正答率(トレーニング) = 0.95
#                 : 340. 正答率(テスト) = 0.9097
# Generation: 350. 正答率(トレーニング) = 0.92
#                 : 350. 正答率(テスト) = 0.8998
# Generation: 360. 正答率(トレーニング) = 0.93
#                 : 360. 正答率(テスト) = 0.9172
# Generation: 370. 正答率(トレーニング) = 0.96
#                 : 370. 正答率(テスト) = 0.9041
# Generation: 380. 正答率(トレーニング) = 0.96
#                 : 380. 正答率(テスト) = 0.9142
# Generation: 390. 正答率(トレーニング) = 0.94
#                 : 390. 正答率(テスト) = 0.9103
# Generation: 400. 正答率(トレーニング) = 0.94
#                 : 400. 正答率(テスト) = 0.9202
# Generation: 410. 正答率(トレーニング) = 0.97
#                 : 410. 正答率(テスト) = 0.918
# Generation: 420. 正答率(トレーニング) = 0.97
#                 : 420. 正答率(テスト) = 0.9203
# Generation: 430. 正答率(トレーニング) = 0.94
#                 : 430. 正答率(テスト) = 0.9058
# Generation: 440. 正答率(トレーニング) = 0.95
#                 : 440. 正答率(テスト) = 0.9237
# Generation: 450. 正答率(トレーニング) = 0.95
#                 : 450. 正答率(テスト) = 0.9236
# Generation: 460. 正答率(トレーニング) = 0.97
#                 : 460. 正答率(テスト) = 0.9262
# Generation: 470. 正答率(トレーニング) = 0.94
#                 : 470. 正答率(テスト) = 0.9235
# Generation: 480. 正答率(トレーニング) = 0.95
#                 : 480. 正答率(テスト) = 0.921
# Generation: 490. 正答率(トレーニング) = 0.94
#                 : 490. 正答率(テスト) = 0.9259
# Generation: 500. 正答率(トレーニング) = 0.95
#                 : 500. 正答率(テスト) = 0.9248
# Generation: 510. 正答率(トレーニング) = 0.95
#                 : 510. 正答率(テスト) = 0.9256
# Generation: 520. 正答率(トレーニング) = 0.97
#                 : 520. 正答率(テスト) = 0.9308
# Generation: 530. 正答率(トレーニング) = 0.95
#                 : 530. 正答率(テスト) = 0.9212
# Generation: 540. 正答率(トレーニング) = 0.99
#                 : 540. 正答率(テスト) = 0.9284
# Generation: 550. 正答率(トレーニング) = 0.94
#                 : 550. 正答率(テスト) = 0.9275
# Generation: 560. 正答率(トレーニング) = 0.96
#                 : 560. 正答率(テスト) = 0.93
# Generation: 570. 正答率(トレーニング) = 0.94
#                 : 570. 正答率(テスト) = 0.9289
# Generation: 580. 正答率(トレーニング) = 0.96
#                 : 580. 正答率(テスト) = 0.9248
# Generation: 590. 正答率(トレーニング) = 0.96
#                 : 590. 正答率(テスト) = 0.9243
# Generation: 600. 正答率(トレーニング) = 0.91
#                 : 600. 正答率(テスト) = 0.9307
# Generation: 610. 正答率(トレーニング) = 0.92
#                 : 610. 正答率(テスト) = 0.9229
# Generation: 620. 正答率(トレーニング) = 0.96
#                 : 620. 正答率(テスト) = 0.9292
# Generation: 630. 正答率(トレーニング) = 0.96
#                 : 630. 正答率(テスト) = 0.9311
# Generation: 640. 正答率(トレーニング) = 0.96
#                 : 640. 正答率(テスト) = 0.9337
# Generation: 650. 正答率(トレーニング) = 0.97
#                 : 650. 正答率(テスト) = 0.9324
# Generation: 660. 正答率(トレーニング) = 0.97
#                 : 660. 正答率(テスト) = 0.9331
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.9295
# Generation: 680. 正答率(トレーニング) = 0.92
#                 : 680. 正答率(テスト) = 0.9252
# Generation: 690. 正答率(トレーニング) = 0.95
#                 : 690. 正答率(テスト) = 0.9336
# Generation: 700. 正答率(トレーニング) = 0.98
#                 : 700. 正答率(テスト) = 0.9334
# Generation: 710. 正答率(トレーニング) = 0.98
#                 : 710. 正答率(テスト) = 0.934
# Generation: 720. 正答率(トレーニング) = 0.98
#                 : 720. 正答率(テスト) = 0.9361
# Generation: 730. 正答率(トレーニング) = 0.96
#                 : 730. 正答率(テスト) = 0.9343
# Generation: 740. 正答率(トレーニング) = 0.96
#                 : 740. 正答率(テスト) = 0.9371
# Generation: 750. 正答率(トレーニング) = 0.95
#                 : 750. 正答率(テスト) = 0.9313
# Generation: 760. 正答率(トレーニング) = 0.97
#                 : 760. 正答率(テスト) = 0.9366
# Generation: 770. 正答率(トレーニング) = 0.99
#                 : 770. 正答率(テスト) = 0.9366
# Generation: 780. 正答率(トレーニング) = 0.96
#                 : 780. 正答率(テスト) = 0.9325
# Generation: 790. 正答率(トレーニング) = 0.93
#                 : 790. 正答率(テスト) = 0.9348
# Generation: 800. 正答率(トレーニング) = 0.97
#                 : 800. 正答率(テスト) = 0.9361
# Generation: 810. 正答率(トレーニング) = 0.96
#                 : 810. 正答率(テスト) = 0.9371
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.936
# Generation: 830. 正答率(トレーニング) = 0.99
#                 : 830. 正答率(テスト) = 0.9317
# Generation: 840. 正答率(トレーニング) = 0.96
#                 : 840. 正答率(テスト) = 0.9349
# Generation: 850. 正答率(トレーニング) = 0.97
#                 : 850. 正答率(テスト) = 0.9383
# Generation: 860. 正答率(トレーニング) = 0.98
#                 : 860. 正答率(テスト) = 0.9396
# Generation: 870. 正答率(トレーニング) = 0.97
#                 : 870. 正答率(テスト) = 0.9334
# Generation: 880. 正答率(トレーニング) = 0.94
#                 : 880. 正答率(テスト) = 0.9417
# Generation: 890. 正答率(トレーニング) = 0.99
#                 : 890. 正答率(テスト) = 0.94
# Generation: 900. 正答率(トレーニング) = 0.93
#                 : 900. 正答率(テスト) = 0.94
# Generation: 910. 正答率(トレーニング) = 0.99
#                 : 910. 正答率(テスト) = 0.9402
# Generation: 920. 正答率(トレーニング) = 0.96
#                 : 920. 正答率(テスト) = 0.9355
# Generation: 930. 正答率(トレーニング) = 0.96
#                 : 930. 正答率(テスト) = 0.934
# Generation: 940. 正答率(トレーニング) = 0.96
#                 : 940. 正答率(テスト) = 0.944
# Generation: 950. 正答率(トレーニング) = 0.98
#                 : 950. 正答率(テスト) = 0.941
# Generation: 960. 正答率(トレーニング) = 0.98
#                 : 960. 正答率(テスト) = 0.9437
# Generation: 970. 正答率(トレーニング) = 0.96
#                 : 970. 正答率(テスト) = 0.9377
# Generation: 980. 正答率(トレーニング) = 0.98
#                 : 980. 正答率(テスト) = 0.9414
# Generation: 990. 正答率(トレーニング) = 0.99
#                 : 990. 正答率(テスト) = 0.9416
# Generation: 1000. 正答率(トレーニング) = 0.96
#                 : 1000. 正答率(テスト) = 0.9379
# Generation: 1010. 正答率(トレーニング) = 0.97
#                 : 1010. 正答率(テスト) = 0.9405
# Generation: 1020. 正答率(トレーニング) = 0.98
#                 : 1020. 正答率(テスト) = 0.9394
# Generation: 1030. 正答率(トレーニング) = 0.96
#                 : 1030. 正答率(テスト) = 0.9423
# Generation: 1040. 正答率(トレーニング) = 1.0
#                 : 1040. 正答率(テスト) = 0.941
# Generation: 1050. 正答率(トレーニング) = 0.97
#                 : 1050. 正答率(テスト) = 0.9413
# Generation: 1060. 正答率(トレーニング) = 0.96
#                 : 1060. 正答率(テスト) = 0.9392
# Generation: 1070. 正答率(トレーニング) = 0.93
#                 : 1070. 正答率(テスト) = 0.9419
# Generation: 1080. 正答率(トレーニング) = 0.94
#                 : 1080. 正答率(テスト) = 0.9418
# Generation: 1090. 正答率(トレーニング) = 0.98
#                 : 1090. 正答率(テスト) = 0.9402
# Generation: 1100. 正答率(トレーニング) = 0.97
#                 : 1100. 正答率(テスト) = 0.934
# Generation: 1110. 正答率(トレーニング) = 0.96
#                 : 1110. 正答率(テスト) = 0.9424
# Generation: 1120. 正答率(トレーニング) = 0.98
#                 : 1120. 正答率(テスト) = 0.942
# Generation: 1130. 正答率(トレーニング) = 0.98
#                 : 1130. 正答率(テスト) = 0.9426
# Generation: 1140. 正答率(トレーニング) = 0.97
#                 : 1140. 正答率(テスト) = 0.9431
# Generation: 1150. 正答率(トレーニング) = 1.0
#                 : 1150. 正答率(テスト) = 0.9439
# Generation: 1160. 正答率(トレーニング) = 0.97
#                 : 1160. 正答率(テスト) = 0.9402
# Generation: 1170. 正答率(トレーニング) = 0.95
#                 : 1170. 正答率(テスト) = 0.9447
# Generation: 1180. 正答率(トレーニング) = 0.98
#                 : 1180. 正答率(テスト) = 0.9473
# Generation: 1190. 正答率(トレーニング) = 0.98
#                 : 1190. 正答率(テスト) = 0.9429
# Generation: 1200. 正答率(トレーニング) = 0.96
#                 : 1200. 正答率(テスト) = 0.9376
# Generation: 1210. 正答率(トレーニング) = 0.98
#                 : 1210. 正答率(テスト) = 0.9467
# Generation: 1220. 正答率(トレーニング) = 0.97
#                 : 1220. 正答率(テスト) = 0.9419
# Generation: 1230. 正答率(トレーニング) = 0.94
#                 : 1230. 正答率(テスト) = 0.9446
# Generation: 1240. 正答率(トレーニング) = 1.0
#                 : 1240. 正答率(テスト) = 0.9454
# Generation: 1250. 正答率(トレーニング) = 0.98
#                 : 1250. 正答率(テスト) = 0.9429
# Generation: 1260. 正答率(トレーニング) = 0.98
#                 : 1260. 正答率(テスト) = 0.9456
# Generation: 1270. 正答率(トレーニング) = 0.95
#                 : 1270. 正答率(テスト) = 0.9435
# Generation: 1280. 正答率(トレーニング) = 0.98
#                 : 1280. 正答率(テスト) = 0.946
# Generation: 1290. 正答率(トレーニング) = 1.0
#                 : 1290. 正答率(テスト) = 0.9413
# Generation: 1300. 正答率(トレーニング) = 0.96
#                 : 1300. 正答率(テスト) = 0.9436
# Generation: 1310. 正答率(トレーニング) = 0.99
#                 : 1310. 正答率(テスト) = 0.9454
# Generation: 1320. 正答率(トレーニング) = 0.96
#                 : 1320. 正答率(テスト) = 0.9479
# Generation: 1330. 正答率(トレーニング) = 0.97
#                 : 1330. 正答率(テスト) = 0.9459
# Generation: 1340. 正答率(トレーニング) = 0.95
#                 : 1340. 正答率(テスト) = 0.9488
# Generation: 1350. 正答率(トレーニング) = 0.96
#                 : 1350. 正答率(テスト) = 0.9491
# Generation: 1360. 正答率(トレーニング) = 0.96
#                 : 1360. 正答率(テスト) = 0.9418
# Generation: 1370. 正答率(トレーニング) = 1.0
#                 : 1370. 正答率(テスト) = 0.947
# Generation: 1380. 正答率(トレーニング) = 1.0
#                 : 1380. 正答率(テスト) = 0.9495
# Generation: 1390. 正答率(トレーニング) = 0.97
#                 : 1390. 正答率(テスト) = 0.9506
# Generation: 1400. 正答率(トレーニング) = 0.99
#                 : 1400. 正答率(テスト) = 0.9501
# Generation: 1410. 正答率(トレーニング) = 0.98
#                 : 1410. 正答率(テスト) = 0.946
# Generation: 1420. 正答率(トレーニング) = 0.96
#                 : 1420. 正答率(テスト) = 0.9497
# Generation: 1430. 正答率(トレーニング) = 0.99
#                 : 1430. 正答率(テスト) = 0.9488
# Generation: 1440. 正答率(トレーニング) = 0.97
#                 : 1440. 正答率(テスト) = 0.9492
# Generation: 1450. 正答率(トレーニング) = 0.98
#                 : 1450. 正答率(テスト) = 0.9444
# Generation: 1460. 正答率(トレーニング) = 0.98
#                 : 1460. 正答率(テスト) = 0.9475
# Generation: 1470. 正答率(トレーニング) = 0.98
#                 : 1470. 正答率(テスト) = 0.9508
# Generation: 1480. 正答率(トレーニング) = 0.99
#                 : 1480. 正答率(テスト) = 0.9503
# Generation: 1490. 正答率(トレーニング) = 0.98
#                 : 1490. 正答率(テスト) = 0.9486
# Generation: 1500. 正答率(トレーニング) = 0.99
#                 : 1500. 正答率(テスト) = 0.9479
# Generation: 1510. 正答率(トレーニング) = 0.98
#                 : 1510. 正答率(テスト) = 0.9494
# Generation: 1520. 正答率(トレーニング) = 0.98
#                 : 1520. 正答率(テスト) = 0.9488
# Generation: 1530. 正答率(トレーニング) = 1.0
#                 : 1530. 正答率(テスト) = 0.9526
# Generation: 1540. 正答率(トレーニング) = 0.96
#                 : 1540. 正答率(テスト) = 0.9483
# Generation: 1550. 正答率(トレーニング) = 0.98
#                 : 1550. 正答率(テスト) = 0.9486
# Generation: 1560. 正答率(トレーニング) = 0.93
#                 : 1560. 正答率(テスト) = 0.9496
# Generation: 1570. 正答率(トレーニング) = 0.99
#                 : 1570. 正答率(テスト) = 0.9524
# Generation: 1580. 正答率(トレーニング) = 0.97
#                 : 1580. 正答率(テスト) = 0.9507
# Generation: 1590. 正答率(トレーニング) = 0.99
#                 : 1590. 正答率(テスト) = 0.9509
# Generation: 1600. 正答率(トレーニング) = 0.99
#                 : 1600. 正答率(テスト) = 0.9528
# Generation: 1610. 正答率(トレーニング) = 0.98
#                 : 1610. 正答率(テスト) = 0.9512
# Generation: 1620. 正答率(トレーニング) = 0.97
#                 : 1620. 正答率(テスト) = 0.9502
# Generation: 1630. 正答率(トレーニング) = 0.98
#                 : 1630. 正答率(テスト) = 0.9541
# Generation: 1640. 正答率(トレーニング) = 0.99
#                 : 1640. 正答率(テスト) = 0.9521
# Generation: 1650. 正答率(トレーニング) = 1.0
#                 : 1650. 正答率(テスト) = 0.9462
# Generation: 1660. 正答率(トレーニング) = 0.99
#                 : 1660. 正答率(テスト) = 0.9489
# Generation: 1670. 正答率(トレーニング) = 0.95
#                 : 1670. 正答率(テスト) = 0.9526
# Generation: 1680. 正答率(トレーニング) = 0.98
#                 : 1680. 正答率(テスト) = 0.9515
# Generation: 1690. 正答率(トレーニング) = 0.97
#                 : 1690. 正答率(テスト) = 0.9518
# Generation: 1700. 正答率(トレーニング) = 1.0
#                 : 1700. 正答率(テスト) = 0.9554
# Generation: 1710. 正答率(トレーニング) = 0.99
#                 : 1710. 正答率(テスト) = 0.9518
# Generation: 1720. 正答率(トレーニング) = 0.97
#                 : 1720. 正答率(テスト) = 0.9519
# Generation: 1730. 正答率(トレーニング) = 0.97
#                 : 1730. 正答率(テスト) = 0.9536
# Generation: 1740. 正答率(トレーニング) = 0.99
#                 : 1740. 正答率(テスト) = 0.9559
# Generation: 1750. 正答率(トレーニング) = 1.0
#                 : 1750. 正答率(テスト) = 0.954
# Generation: 1760. 正答率(トレーニング) = 0.98
#                 : 1760. 正答率(テスト) = 0.9539
# Generation: 1770. 正答率(トレーニング) = 0.99
#                 : 1770. 正答率(テスト) = 0.9537
# Generation: 1780. 正答率(トレーニング) = 0.97
#                 : 1780. 正答率(テスト) = 0.954
# Generation: 1790. 正答率(トレーニング) = 0.97
#                 : 1790. 正答率(テスト) = 0.9521
# Generation: 1800. 正答率(トレーニング) = 0.99
#                 : 1800. 正答率(テスト) = 0.9515
# Generation: 1810. 正答率(トレーニング) = 0.98
#                 : 1810. 正答率(テスト) = 0.9511
# Generation: 1820. 正答率(トレーニング) = 0.98
#                 : 1820. 正答率(テスト) = 0.9565
# Generation: 1830. 正答率(トレーニング) = 0.97
#                 : 1830. 正答率(テスト) = 0.951
# Generation: 1840. 正答率(トレーニング) = 1.0
#                 : 1840. 正答率(テスト) = 0.953
# Generation: 1850. 正答率(トレーニング) = 0.98
#                 : 1850. 正答率(テスト) = 0.9544
# Generation: 1860. 正答率(トレーニング) = 0.96
#                 : 1860. 正答率(テスト) = 0.9549
# Generation: 1870. 正答率(トレーニング) = 1.0
#                 : 1870. 正答率(テスト) = 0.9558
# Generation: 1880. 正答率(トレーニング) = 0.95
#                 : 1880. 正答率(テスト) = 0.9528
# Generation: 1890. 正答率(トレーニング) = 0.99
#                 : 1890. 正答率(テスト) = 0.9528
# Generation: 1900. 正答率(トレーニング) = 0.98
#                 : 1900. 正答率(テスト) = 0.9554
# Generation: 1910. 正答率(トレーニング) = 0.99
#                 : 1910. 正答率(テスト) = 0.9516
# Generation: 1920. 正答率(トレーニング) = 0.95
#                 : 1920. 正答率(テスト) = 0.9523
# Generation: 1930. 正答率(トレーニング) = 1.0
#                 : 1930. 正答率(テスト) = 0.9576
# Generation: 1940. 正答率(トレーニング) = 0.98
#                 : 1940. 正答率(テスト) = 0.9549
# Generation: 1950. 正答率(トレーニング) = 0.97
#                 : 1950. 正答率(テスト) = 0.9525
# Generation: 1960. 正答率(トレーニング) = 0.97
#                 : 1960. 正答率(テスト) = 0.9533
# Generation: 1970. 正答率(トレーニング) = 0.93
#                 : 1970. 正答率(テスト) = 0.952
# Generation: 1980. 正答率(トレーニング) = 0.98
#                 : 1980. 正答率(テスト) = 0.9517
# Generation: 1990. 正答率(トレーニング) = 0.99
#                 : 1990. 正答率(テスト) = 0.953
# Generation: 2000. 正答率(トレーニング) = 0.99
#                 : 2000. 正答率(テスト) = 0.9576

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] hidden_size_listの数字を変更してみよう

# %% [markdown]
# ## [try] sigmoid - He と relu - Xavier についても試してみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
